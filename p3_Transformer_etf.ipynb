# %%
# Imports, random seed, and device configuration
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import random
import time
import math
import matplotlib.pyplot as plt
import seaborn as sns

# Set random seed for reproducibility
random_seed = 42
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(random_seed)
    
# make cudnn deterministic
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

# Set device to GPU if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Load translation dataset from file ("Dataset-English_to_French.txt")
with open("Dataset-English_to_French.txt", "r", encoding="utf-8") as f:
    data_str = f.read()
exec(data_str)  # This defines variable 'english_to_french'

# Build word-level vocabulary from English and French sentences
all_words = []
for eng, fr in english_to_french:
    all_words.extend(eng.split())
    all_words.extend(fr.split())
vocab = sorted(list(set(all_words)))
# Define special tokens: SOS (start) and EOS (end)
SOS_token = 0
EOS_token = 1
word_to_index = {"SOS": SOS_token, "EOS": EOS_token}
for i, word in enumerate(vocab):
    word_to_index[word] = i + 2
index_to_word = {i: word for word, i in word_to_index.items()}
print("Vocabulary size:", len(word_to_index))
# Print sample data to verify
print("\nSample data (first 5):")
for i, sample in enumerate(english_to_french[:5]):
    print(f"Sample {i+1}:", sample)
# Out:
# Vocabulary size: 511
#
# Sample data (first 5):
# Sample 1: ('I am cold', "J'ai froid")
# Sample 2: ('You are tired', 'Tu es fatigué')
# Sample 3: ('He is hungry', 'Il a faim')
# Sample 4: ('She is happy', 'Elle est heureuse')
# Sample 5: ('We are friends', 'Nous sommes amis')

# %%
# Define custom Dataset for English-to-French translation (word-based)
class TranslationDataset(Dataset):
    def __init__(self, data, word_to_index):
        self.data = data
        self.word_to_index = word_to_index

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        eng, fr = self.data[idx]
        # Tokenize by splitting on whitespace and append EOS token
        input_tensor = torch.tensor([self.word_to_index[word] for word in eng.split()] + [EOS_token], dtype=torch.long)
        target_tensor = torch.tensor([self.word_to_index[word] for word in fr.split()] + [EOS_token], dtype=torch.long)
        return input_tensor, target_tensor

dataset = TranslationDataset(english_to_french, word_to_index)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %%
# RNN-based GRU Encoder-Decoder (Without Attention)
# Define GRU-based Encoder (word-based)
class EncoderGRU(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderGRU, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)  # (1,1,hidden)
        output, hidden = self.gru(embedded, hidden)
        return output, hidden
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# Define GRU-based Decoder (word-based) without attention
class DecoderGRU(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderGRU, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output, hidden = self.gru(embedded, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# Instantiate models for RNN baseline (without attention)
input_size = len(word_to_index)
hidden_size = 256
output_size = len(word_to_index)
encoder_gru = EncoderGRU(input_size, hidden_size).to(device)
decoder_gru = DecoderGRU(hidden_size, output_size).to(device)

# %%
# Training and evaluation functions for RNN (without attention)
def train_rnn(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion):
    input_tensor = input_tensor.squeeze(0)
    target_tensor = target_tensor.squeeze(0)
    encoder_hidden = encoder.initHidden()
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    loss = 0
    # Encoder pass
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei].unsqueeze(0), encoder_hidden)
    # Decoder pass starting with SOS token
    decoder_input = torch.tensor([SOS_token], device=device)
    decoder_hidden = encoder_hidden
    predicted_indices = []
    for di in range(target_length):
        decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
        loss += criterion(decoder_output, target_tensor[di].unsqueeze(0))
        topv, topi = decoder_output.topk(1)
        predicted_indices.append(topi.item())
        decoder_input = topi.squeeze().detach()
        if decoder_input.item() == EOS_token:
            break
    loss.backward()
    encoder_optimizer.step()
    decoder_optimizer.step()
    return loss.item() / target_length, predicted_indices

def evaluate_rnn(encoder, decoder, dataloader, criterion):
    encoder.eval()
    decoder.eval()
    total_loss = 0
    total_correct = 0
    total_tokens = 0
    total_samples = 0
    with torch.no_grad():
        for input_tensor, target_tensor in dataloader:
            input_tensor = input_tensor.squeeze(0).to(device)
            target_tensor = target_tensor.squeeze(0).to(device)
            encoder_hidden = encoder.initHidden()
            input_length = input_tensor.size(0)
            target_length = target_tensor.size(0)
            loss = 0
            predicted_indices = []
            for ei in range(input_length):
                encoder_output, encoder_hidden = encoder(input_tensor[ei].unsqueeze(0), encoder_hidden)
            decoder_input = torch.tensor([SOS_token], device=device)
            decoder_hidden = encoder_hidden
            for di in range(target_length):
                decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
                loss += criterion(decoder_output, target_tensor[di].unsqueeze(0))
                topv, topi = decoder_output.topk(1)
                predicted_indices.append(topi.item())
                decoder_input = topi.squeeze().detach()
                if decoder_input.item() == EOS_token:
                    break
            total_loss += loss.item() / target_length
            correct = sum(1 for i in range(target_length) if i < len(predicted_indices) and predicted_indices[i] == target_tensor[i].item())
            total_correct += correct
            total_tokens += target_length
            total_samples += 1
    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_tokens
    return avg_loss, accuracy

# %%
# Training loop for RNN (without attention)
encoder_optimizer = optim.SGD(encoder_gru.parameters(), lr=0.01)
decoder_optimizer = optim.SGD(decoder_gru.parameters(), lr=0.01)
criterion = nn.NLLLoss()

n_epochs = 100
rnn_train_losses = []
rnn_val_losses = []
rnn_val_accuracies = []

for epoch in range(n_epochs):
    total_loss = 0
    encoder_gru.train()
    decoder_gru.train()
    for input_tensor, target_tensor in dataloader:
        input_tensor = input_tensor.to(device)
        target_tensor = target_tensor.to(device)
        loss, _ = train_rnn(input_tensor, target_tensor, encoder_gru, decoder_gru, encoder_optimizer, decoder_optimizer, criterion)
        total_loss += loss
    avg_train_loss = total_loss / len(dataloader)
    rnn_train_losses.append(avg_train_loss)
    val_loss, val_acc = evaluate_rnn(encoder_gru, decoder_gru, dataloader, criterion)
    rnn_val_losses.append(val_loss)
    rnn_val_accuracies.append(val_acc)
    print(f"[RNN] Epoch {epoch+1}: Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# [RNN] Epoch 1: Train Loss: 3.4602, Val Loss: 2.6668, Val Acc: 0.0415
# [RNN] Epoch 2: Train Loss: 3.2418, Val Loss: 3.2976, Val Acc: 0.0876
# [RNN] Epoch 3: Train Loss: 3.2661, Val Loss: 3.7903, Val Acc: 0.1398
# [RNN] Epoch 4: Train Loss: 3.4136, Val Loss: 3.0986, Val Acc: 0.0737
# [RNN] Epoch 5: Train Loss: 3.2980, Val Loss: 3.4560, Val Acc: 0.1413
# [RNN] Epoch 6: Train Loss: 3.1912, Val Loss: 2.8371, Val Acc: 0.1582
# [RNN] Epoch 7: Train Loss: 3.1284, Val Loss: 2.7239, Val Acc: 0.1551
# [RNN] Epoch 8: Train Loss: 2.9424, Val Loss: 2.5760, Val Acc: 0.1720
# [RNN] Epoch 9: Train Loss: 2.8164, Val Loss: 2.4977, Val Acc: 0.2396
# [RNN] Epoch 10: Train Loss: 2.6353, Val Loss: 2.6423, Val Acc: 0.2873
# [RNN] Epoch 11: Train Loss: 2.5522, Val Loss: 2.1640, Val Acc: 0.2535
# [RNN] Epoch 12: Train Loss: 2.3651, Val Loss: 2.3858, Val Acc: 0.3057
# [RNN] Epoch 13: Train Loss: 2.3119, Val Loss: 2.1964, Val Acc: 0.3072
# [RNN] Epoch 14: Train Loss: 2.1294, Val Loss: 2.0037, Val Acc: 0.3364
# [RNN] Epoch 15: Train Loss: 2.1202, Val Loss: 1.9891, Val Acc: 0.3917
# [RNN] Epoch 16: Train Loss: 2.0357, Val Loss: 1.8538, Val Acc: 0.4470
# [RNN] Epoch 17: Train Loss: 1.9011, Val Loss: 1.5989, Val Acc: 0.4424
# [RNN] Epoch 18: Train Loss: 1.7720, Val Loss: 1.6153, Val Acc: 0.5146
# [RNN] Epoch 19: Train Loss: 1.6624, Val Loss: 1.4120, Val Acc: 0.5637
# [RNN] Epoch 20: Train Loss: 1.4930, Val Loss: 1.1956, Val Acc: 0.5637
# [RNN] Epoch 21: Train Loss: 1.3728, Val Loss: 1.1946, Val Acc: 0.6621
# [RNN] Epoch 22: Train Loss: 1.2555, Val Loss: 1.1120, Val Acc: 0.6820
# [RNN] Epoch 23: Train Loss: 1.1175, Val Loss: 0.9795, Val Acc: 0.7634
# [RNN] Epoch 24: Train Loss: 0.9326, Val Loss: 0.7931, Val Acc: 0.8080
# [RNN] Epoch 25: Train Loss: 0.8493, Val Loss: 0.7711, Val Acc: 0.8341
# [RNN] Epoch 26: Train Loss: 0.7349, Val Loss: 0.5788, Val Acc: 0.8817
# [RNN] Epoch 27: Train Loss: 0.6138, Val Loss: 0.4532, Val Acc: 0.8618
# [RNN] Epoch 28: Train Loss: 0.5073, Val Loss: 0.4174, Val Acc: 0.9171
# [RNN] Epoch 29: Train Loss: 0.4357, Val Loss: 0.3688, Val Acc: 0.9370
# [RNN] Epoch 30: Train Loss: 0.3801, Val Loss: 0.2871, Val Acc: 0.9324
# [RNN] Epoch 31: Train Loss: 0.3009, Val Loss: 0.2459, Val Acc: 0.9585
# [RNN] Epoch 32: Train Loss: 0.2582, Val Loss: 0.2199, Val Acc: 0.9662
# [RNN] Epoch 33: Train Loss: 0.2242, Val Loss: 0.1865, Val Acc: 0.9677
# [RNN] Epoch 34: Train Loss: 0.2016, Val Loss: 0.1614, Val Acc: 0.9754
# [RNN] Epoch 35: Train Loss: 0.1696, Val Loss: 0.1235, Val Acc: 0.9877
# [RNN] Epoch 36: Train Loss: 0.1306, Val Loss: 0.1162, Val Acc: 0.9908
# [RNN] Epoch 37: Train Loss: 0.1236, Val Loss: 0.1090, Val Acc: 0.9908
# [RNN] Epoch 38: Train Loss: 0.1155, Val Loss: 0.0979, Val Acc: 0.9923
# [RNN] Epoch 39: Train Loss: 0.1020, Val Loss: 0.0849, Val Acc: 0.9969
# [RNN] Epoch 40: Train Loss: 0.0887, Val Loss: 0.0761, Val Acc: 0.9954
# [RNN] Epoch 41: Train Loss: 0.0801, Val Loss: 0.0696, Val Acc: 1.0000
# [RNN] Epoch 42: Train Loss: 0.0727, Val Loss: 0.0634, Val Acc: 1.0000
# [RNN] Epoch 43: Train Loss: 0.0662, Val Loss: 0.0586, Val Acc: 1.0000
# [RNN] Epoch 44: Train Loss: 0.0611, Val Loss: 0.0547, Val Acc: 1.0000
# [RNN] Epoch 45: Train Loss: 0.0569, Val Loss: 0.0513, Val Acc: 1.0000
# [RNN] Epoch 46: Train Loss: 0.0533, Val Loss: 0.0484, Val Acc: 1.0000
# [RNN] Epoch 47: Train Loss: 0.0502, Val Loss: 0.0459, Val Acc: 1.0000
# [RNN] Epoch 48: Train Loss: 0.0474, Val Loss: 0.0436, Val Acc: 1.0000
# [RNN] Epoch 49: Train Loss: 0.0450, Val Loss: 0.0415, Val Acc: 1.0000
# [RNN] Epoch 50: Train Loss: 0.0428, Val Loss: 0.0396, Val Acc: 1.0000
# [RNN] Epoch 51: Train Loss: 0.0408, Val Loss: 0.0379, Val Acc: 1.0000
# [RNN] Epoch 52: Train Loss: 0.0389, Val Loss: 0.0363, Val Acc: 1.0000
# [RNN] Epoch 53: Train Loss: 0.0373, Val Loss: 0.0348, Val Acc: 1.0000
# [RNN] Epoch 54: Train Loss: 0.0357, Val Loss: 0.0335, Val Acc: 1.0000
# [RNN] Epoch 55: Train Loss: 0.0344, Val Loss: 0.0322, Val Acc: 1.0000
# [RNN] Epoch 56: Train Loss: 0.0330, Val Loss: 0.0311, Val Acc: 1.0000
# [RNN] Epoch 57: Train Loss: 0.0318, Val Loss: 0.0300, Val Acc: 1.0000
# [RNN] Epoch 58: Train Loss: 0.0307, Val Loss: 0.0290, Val Acc: 1.0000
# [RNN] Epoch 59: Train Loss: 0.0297, Val Loss: 0.0281, Val Acc: 1.0000
# [RNN] Epoch 60: Train Loss: 0.0287, Val Loss: 0.0272, Val Acc: 1.0000
# [RNN] Epoch 61: Train Loss: 0.0278, Val Loss: 0.0264, Val Acc: 1.0000
# [RNN] Epoch 62: Train Loss: 0.0269, Val Loss: 0.0256, Val Acc: 1.0000
# [RNN] Epoch 63: Train Loss: 0.0261, Val Loss: 0.0248, Val Acc: 1.0000
# [RNN] Epoch 64: Train Loss: 0.0253, Val Loss: 0.0241, Val Acc: 1.0000
# [RNN] Epoch 65: Train Loss: 0.0246, Val Loss: 0.0235, Val Acc: 1.0000
# [RNN] Epoch 66: Train Loss: 0.0239, Val Loss: 0.0229, Val Acc: 1.0000
# [RNN] Epoch 67: Train Loss: 0.0233, Val Loss: 0.0223, Val Acc: 1.0000
# [RNN] Epoch 68: Train Loss: 0.0227, Val Loss: 0.0217, Val Acc: 1.0000
# [RNN] Epoch 69: Train Loss: 0.0221, Val Loss: 0.0212, Val Acc: 1.0000
# [RNN] Epoch 70: Train Loss: 0.0215, Val Loss: 0.0207, Val Acc: 1.0000
# [RNN] Epoch 71: Train Loss: 0.0210, Val Loss: 0.0202, Val Acc: 1.0000
# [RNN] Epoch 72: Train Loss: 0.0205, Val Loss: 0.0197, Val Acc: 1.0000
# [RNN] Epoch 73: Train Loss: 0.0200, Val Loss: 0.0193, Val Acc: 1.0000
# [RNN] Epoch 74: Train Loss: 0.0195, Val Loss: 0.0188, Val Acc: 1.0000
# [RNN] Epoch 75: Train Loss: 0.0191, Val Loss: 0.0184, Val Acc: 1.0000
# [RNN] Epoch 76: Train Loss: 0.0187, Val Loss: 0.0180, Val Acc: 1.0000
# [RNN] Epoch 77: Train Loss: 0.0183, Val Loss: 0.0177, Val Acc: 1.0000
# [RNN] Epoch 78: Train Loss: 0.0179, Val Loss: 0.0173, Val Acc: 1.0000
# [RNN] Epoch 79: Train Loss: 0.0175, Val Loss: 0.0169, Val Acc: 1.0000
# [RNN] Epoch 80: Train Loss: 0.0172, Val Loss: 0.0166, Val Acc: 1.0000
# [RNN] Epoch 81: Train Loss: 0.0168, Val Loss: 0.0163, Val Acc: 1.0000
# [RNN] Epoch 82: Train Loss: 0.0165, Val Loss: 0.0160, Val Acc: 1.0000
# [RNN] Epoch 83: Train Loss: 0.0162, Val Loss: 0.0157, Val Acc: 1.0000
# [RNN] Epoch 84: Train Loss: 0.0159, Val Loss: 0.0154, Val Acc: 1.0000
# [RNN] Epoch 85: Train Loss: 0.0156, Val Loss: 0.0151, Val Acc: 1.0000
# [RNN] Epoch 86: Train Loss: 0.0153, Val Loss: 0.0149, Val Acc: 1.0000
# [RNN] Epoch 87: Train Loss: 0.0150, Val Loss: 0.0146, Val Acc: 1.0000
# [RNN] Epoch 88: Train Loss: 0.0148, Val Loss: 0.0143, Val Acc: 1.0000
# [RNN] Epoch 89: Train Loss: 0.0145, Val Loss: 0.0141, Val Acc: 1.0000
# [RNN] Epoch 90: Train Loss: 0.0143, Val Loss: 0.0139, Val Acc: 1.0000
# [RNN] Epoch 91: Train Loss: 0.0140, Val Loss: 0.0136, Val Acc: 1.0000
# [RNN] Epoch 92: Train Loss: 0.0138, Val Loss: 0.0134, Val Acc: 1.0000
# [RNN] Epoch 93: Train Loss: 0.0136, Val Loss: 0.0132, Val Acc: 1.0000
# [RNN] Epoch 94: Train Loss: 0.0134, Val Loss: 0.0130, Val Acc: 1.0000
# [RNN] Epoch 95: Train Loss: 0.0131, Val Loss: 0.0128, Val Acc: 1.0000
# [RNN] Epoch 96: Train Loss: 0.0129, Val Loss: 0.0126, Val Acc: 1.0000
# [RNN] Epoch 97: Train Loss: 0.0127, Val Loss: 0.0124, Val Acc: 1.0000
# [RNN] Epoch 98: Train Loss: 0.0125, Val Loss: 0.0122, Val Acc: 1.0000
# [RNN] Epoch 99: Train Loss: 0.0124, Val Loss: 0.0121, Val Acc: 1.0000
# [RNN] Epoch 100: Train Loss: 0.0122, Val Loss: 0.0119, Val Acc: 1.0000

# %%
# RNN-based GRU Encoder-Decoder with Attention
# Define GRU Encoder (reuse EncoderGRU from above)
# Define Attention-based Decoder
class AttnDecoderGRU(nn.Module):
    def __init__(self, hidden_size, output_size, max_length=50, dropout_p=0.1):
        super(AttnDecoderGRU, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.max_length = max_length
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attn = nn.Linear(hidden_size * 2, max_length)
        self.attn_combine = nn.Linear(hidden_size * 2, hidden_size)
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)
    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)
        attn_input = torch.cat((embedded[0], hidden[0]), 1)  # (1, hidden*2)
        attn_weights = torch.softmax(self.attn(attn_input), dim=1)  # (1, max_length)
        attn_weights_unsqueezed = attn_weights.unsqueeze(1)  # (1, 1, max_length)
        encoder_outputs_unsqueezed = encoder_outputs.unsqueeze(0)  # (1, max_length, hidden)
        context = torch.bmm(attn_weights_unsqueezed, encoder_outputs_unsqueezed)  # (1,1,hidden)
        output = torch.cat((embedded[0], context[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)
        output = torch.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden, attn_weights
    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# Instantiate models for attention version
encoder_attn = EncoderGRU(input_size, hidden_size).to(device)
decoder_attn = AttnDecoderGRU(hidden_size, output_size, max_length=50, dropout_p=0.1).to(device)

# %%
# Training and evaluation functions for attention model
def train_attn(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=50):
    input_tensor = input_tensor.squeeze(0)
    target_tensor = target_tensor.squeeze(0)
    encoder_hidden = encoder.initHidden()
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
    loss = 0
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei].unsqueeze(0), encoder_hidden)
        if ei < max_length:
            encoder_outputs[ei] = encoder_output[0, 0]
    decoder_input = torch.tensor([SOS_token], device=device)
    decoder_hidden = encoder_hidden
    predicted_indices = []
    for di in range(target_length):
        decoder_output, decoder_hidden, attn_weights = decoder(decoder_input, decoder_hidden, encoder_outputs)
        loss += criterion(decoder_output, target_tensor[di].unsqueeze(0))
        topv, topi = decoder_output.topk(1)
        predicted_indices.append(topi.item())
        decoder_input = topi.squeeze().detach()
        if decoder_input.item() == EOS_token:
            break
    loss.backward()
    encoder_optimizer.step()
    decoder_optimizer.step()
    return loss.item() / target_length, predicted_indices

def evaluate_attn(encoder, decoder, dataloader, criterion, max_length=50):
    encoder.eval()
    decoder.eval()
    total_loss = 0
    total_correct = 0
    total_tokens = 0
    total_samples = 0
    with torch.no_grad():
        for input_tensor, target_tensor in dataloader:
            input_tensor = input_tensor.squeeze(0).to(device)
            target_tensor = target_tensor.squeeze(0).to(device)
            encoder_hidden = encoder.initHidden()
            input_length = input_tensor.size(0)
            target_length = target_tensor.size(0)
            encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
            loss = 0
            predicted_indices = []
            for ei in range(input_length):
                encoder_output, encoder_hidden = encoder(input_tensor[ei].unsqueeze(0), encoder_hidden)
                if ei < max_length:
                    encoder_outputs[ei] = encoder_output[0, 0]
            decoder_input = torch.tensor([SOS_token], device=device)
            decoder_hidden = encoder_hidden
            for di in range(target_length):
                decoder_output, decoder_hidden, attn_weights = decoder(decoder_input, decoder_hidden, encoder_outputs)
                loss += criterion(decoder_output, target_tensor[di].unsqueeze(0))
                topv, topi = decoder_output.topk(1)
                predicted_indices.append(topi.item())
                decoder_input = topi.squeeze().detach()
                if decoder_input.item() == EOS_token:
                    break
            total_loss += loss.item() / target_length
            correct = sum(1 for i in range(target_length) if i < len(predicted_indices) and predicted_indices[i] == target_tensor[i].item())
            total_correct += correct
            total_tokens += target_length
            total_samples += 1
    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_tokens
    return avg_loss, accuracy

# %%
# Training loop for attention model
encoder_attn_optimizer = optim.SGD(encoder_attn.parameters(), lr=0.01)
decoder_attn_optimizer = optim.SGD(decoder_attn.parameters(), lr=0.01)
criterion_attn = nn.NLLLoss()

attn_train_losses = []
attn_val_losses = []
attn_val_accuracies = []
for epoch in range(n_epochs):
    total_loss = 0
    encoder_attn.train()
    decoder_attn.train()
    for input_tensor, target_tensor in dataloader:
        input_tensor = input_tensor.to(device)
        target_tensor = target_tensor.to(device)
        loss, _ = train_attn(input_tensor, target_tensor, encoder_attn, decoder_attn,
                              encoder_attn_optimizer, decoder_attn_optimizer, criterion_attn, max_length=50)
        total_loss += loss
    avg_train_loss = total_loss / len(dataloader)
    attn_train_losses.append(avg_train_loss)
    val_loss, val_acc = evaluate_attn(encoder_attn, decoder_attn, dataloader, criterion_attn, max_length=50)
    attn_val_losses.append(val_loss)
    attn_val_accuracies.append(val_acc)
    print(f"[Attn] Epoch {epoch+1}: Train Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# [Attn] Epoch 1: Train Loss: 3.7071, Val Loss: 3.3654, Val Acc: 0.0614
# [Attn] Epoch 2: Train Loss: 2.8785, Val Loss: 2.3955, Val Acc: 0.0369
# [Attn] Epoch 3: Train Loss: 3.1806, Val Loss: 2.3277, Val Acc: 0.0430
# [Attn] Epoch 4: Train Loss: 3.2275, Val Loss: 3.1226, Val Acc: 0.0998
# [Attn] Epoch 5: Train Loss: 3.2264, Val Loss: 2.1536, Val Acc: 0.0722
# [Attn] Epoch 6: Train Loss: 3.1484, Val Loss: 3.0523, Val Acc: 0.1720
# [Attn] Epoch 7: Train Loss: 3.0423, Val Loss: 2.6855, Val Acc: 0.1767
# [Attn] Epoch 8: Train Loss: 2.8805, Val Loss: 2.6090, Val Acc: 0.2089
# [Attn] Epoch 9: Train Loss: 2.7809, Val Loss: 2.6666, Val Acc: 0.2627
# [Attn] Epoch 10: Train Loss: 2.6566, Val Loss: 2.6632, Val Acc: 0.2934
# [Attn] Epoch 11: Train Loss: 2.5656, Val Loss: 2.4755, Val Acc: 0.3072
# [Attn] Epoch 12: Train Loss: 2.4636, Val Loss: 2.1587, Val Acc: 0.3226
# [Attn] Epoch 13: Train Loss: 2.2827, Val Loss: 2.1634, Val Acc: 0.3763
# [Attn] Epoch 14: Train Loss: 2.1197, Val Loss: 1.8362, Val Acc: 0.3671
# [Attn] Epoch 15: Train Loss: 1.9493, Val Loss: 1.6356, Val Acc: 0.4255
# [Attn] Epoch 16: Train Loss: 1.7777, Val Loss: 1.6426, Val Acc: 0.5084
# [Attn] Epoch 17: Train Loss: 1.6851, Val Loss: 1.3601, Val Acc: 0.5346
# [Attn] Epoch 18: Train Loss: 1.5345, Val Loss: 1.2295, Val Acc: 0.5730
# [Attn] Epoch 19: Train Loss: 1.3797, Val Loss: 1.0764, Val Acc: 0.5822
# [Attn] Epoch 20: Train Loss: 1.2483, Val Loss: 1.0815, Val Acc: 0.6974
# [Attn] Epoch 21: Train Loss: 1.1695, Val Loss: 0.9287, Val Acc: 0.7650
# [Attn] Epoch 22: Train Loss: 0.9846, Val Loss: 0.8714, Val Acc: 0.8034
# [Attn] Epoch 23: Train Loss: 0.8914, Val Loss: 0.6893, Val Acc: 0.8095
# [Attn] Epoch 24: Train Loss: 0.8156, Val Loss: 0.6066, Val Acc: 0.8510
# [Attn] Epoch 25: Train Loss: 0.6765, Val Loss: 0.5340, Val Acc: 0.8679
# [Attn] Epoch 26: Train Loss: 0.5681, Val Loss: 0.4445, Val Acc: 0.8971
# [Attn] Epoch 27: Train Loss: 0.4796, Val Loss: 0.3699, Val Acc: 0.9063
# [Attn] Epoch 28: Train Loss: 0.4006, Val Loss: 0.3018, Val Acc: 0.9339
# [Attn] Epoch 29: Train Loss: 0.3204, Val Loss: 0.2750, Val Acc: 0.9462
# [Attn] Epoch 30: Train Loss: 0.2856, Val Loss: 0.2251, Val Acc: 0.9570
# [Attn] Epoch 31: Train Loss: 0.2719, Val Loss: 0.2346, Val Acc: 0.9662
# [Attn] Epoch 32: Train Loss: 0.2288, Val Loss: 0.1711, Val Acc: 0.9770
# [Attn] Epoch 33: Train Loss: 0.1838, Val Loss: 0.1482, Val Acc: 0.9770
# [Attn] Epoch 34: Train Loss: 0.1579, Val Loss: 0.1283, Val Acc: 0.9846
# [Attn] Epoch 35: Train Loss: 0.1370, Val Loss: 0.1104, Val Acc: 0.9908
# [Attn] Epoch 36: Train Loss: 0.1187, Val Loss: 0.1032, Val Acc: 0.9908
# [Attn] Epoch 37: Train Loss: 0.1103, Val Loss: 0.0901, Val Acc: 0.9954
# [Attn] Epoch 38: Train Loss: 0.0963, Val Loss: 0.0808, Val Acc: 0.9969
# [Attn] Epoch 39: Train Loss: 0.0864, Val Loss: 0.0738, Val Acc: 0.9969
# [Attn] Epoch 40: Train Loss: 0.0793, Val Loss: 0.0681, Val Acc: 0.9985
# [Attn] Epoch 41: Train Loss: 0.0717, Val Loss: 0.0623, Val Acc: 0.9969
# [Attn] Epoch 42: Train Loss: 0.0662, Val Loss: 0.0593, Val Acc: 0.9985
# [Attn] Epoch 43: Train Loss: 0.0607, Val Loss: 0.0530, Val Acc: 1.0000
# [Attn] Epoch 44: Train Loss: 0.0562, Val Loss: 0.0498, Val Acc: 1.0000
# [Attn] Epoch 45: Train Loss: 0.0524, Val Loss: 0.0466, Val Acc: 1.0000
# [Attn] Epoch 46: Train Loss: 0.0493, Val Loss: 0.0440, Val Acc: 1.0000
# [Attn] Epoch 47: Train Loss: 0.0467, Val Loss: 0.0417, Val Acc: 1.0000
# [Attn] Epoch 48: Train Loss: 0.0440, Val Loss: 0.0396, Val Acc: 1.0000
# [Attn] Epoch 49: Train Loss: 0.0419, Val Loss: 0.0377, Val Acc: 1.0000
# [Attn] Epoch 50: Train Loss: 0.0398, Val Loss: 0.0360, Val Acc: 1.0000
# [Attn] Epoch 51: Train Loss: 0.0381, Val Loss: 0.0345, Val Acc: 1.0000
# [Attn] Epoch 52: Train Loss: 0.0362, Val Loss: 0.0331, Val Acc: 1.0000
# [Attn] Epoch 53: Train Loss: 0.0348, Val Loss: 0.0317, Val Acc: 1.0000
# [Attn] Epoch 54: Train Loss: 0.0334, Val Loss: 0.0305, Val Acc: 1.0000
# [Attn] Epoch 55: Train Loss: 0.0321, Val Loss: 0.0294, Val Acc: 1.0000
# [Attn] Epoch 56: Train Loss: 0.0309, Val Loss: 0.0284, Val Acc: 1.0000
# [Attn] Epoch 57: Train Loss: 0.0300, Val Loss: 0.0274, Val Acc: 1.0000
# [Attn] Epoch 58: Train Loss: 0.0287, Val Loss: 0.0264, Val Acc: 1.0000
# [Attn] Epoch 59: Train Loss: 0.0278, Val Loss: 0.0256, Val Acc: 1.0000
# [Attn] Epoch 60: Train Loss: 0.0269, Val Loss: 0.0248, Val Acc: 1.0000
# [Attn] Epoch 61: Train Loss: 0.0260, Val Loss: 0.0240, Val Acc: 1.0000
# [Attn] Epoch 62: Train Loss: 0.0253, Val Loss: 0.0233, Val Acc: 1.0000
# [Attn] Epoch 63: Train Loss: 0.0244, Val Loss: 0.0227, Val Acc: 1.0000
# [Attn] Epoch 64: Train Loss: 0.0236, Val Loss: 0.0220, Val Acc: 1.0000
# [Attn] Epoch 65: Train Loss: 0.0231, Val Loss: 0.0214, Val Acc: 1.0000
# [Attn] Epoch 66: Train Loss: 0.0225, Val Loss: 0.0209, Val Acc: 1.0000
# [Attn] Epoch 67: Train Loss: 0.0218, Val Loss: 0.0203, Val Acc: 1.0000
# [Attn] Epoch 68: Train Loss: 0.0212, Val Loss: 0.0198, Val Acc: 1.0000
# [Attn] Epoch 69: Train Loss: 0.0207, Val Loss: 0.0193, Val Acc: 1.0000
# [Attn] Epoch 70: Train Loss: 0.0202, Val Loss: 0.0188, Val Acc: 1.0000
# [Attn] Epoch 71: Train Loss: 0.0197, Val Loss: 0.0184, Val Acc: 1.0000
# [Attn] Epoch 72: Train Loss: 0.0192, Val Loss: 0.0180, Val Acc: 1.0000
# [Attn] Epoch 73: Train Loss: 0.0188, Val Loss: 0.0176, Val Acc: 1.0000
# [Attn] Epoch 74: Train Loss: 0.0184, Val Loss: 0.0172, Val Acc: 1.0000
# [Attn] Epoch 75: Train Loss: 0.0180, Val Loss: 0.0168, Val Acc: 1.0000
# [Attn] Epoch 76: Train Loss: 0.0176, Val Loss: 0.0165, Val Acc: 1.0000
# [Attn] Epoch 77: Train Loss: 0.0172, Val Loss: 0.0161, Val Acc: 1.0000
# [Attn] Epoch 78: Train Loss: 0.0171, Val Loss: 0.0158, Val Acc: 1.0000
# [Attn] Epoch 79: Train Loss: 0.0164, Val Loss: 0.0155, Val Acc: 1.0000
# [Attn] Epoch 80: Train Loss: 0.0162, Val Loss: 0.0152, Val Acc: 1.0000
# [Attn] Epoch 81: Train Loss: 0.0158, Val Loss: 0.0149, Val Acc: 1.0000
# [Attn] Epoch 82: Train Loss: 0.0155, Val Loss: 0.0146, Val Acc: 1.0000
# [Attn] Epoch 83: Train Loss: 0.0152, Val Loss: 0.0143, Val Acc: 1.0000
# [Attn] Epoch 84: Train Loss: 0.0150, Val Loss: 0.0141, Val Acc: 1.0000
# [Attn] Epoch 85: Train Loss: 0.0146, Val Loss: 0.0138, Val Acc: 1.0000
# [Attn] Epoch 86: Train Loss: 0.0144, Val Loss: 0.0136, Val Acc: 1.0000
# [Attn] Epoch 87: Train Loss: 0.0142, Val Loss: 0.0133, Val Acc: 1.0000
# [Attn] Epoch 88: Train Loss: 0.0140, Val Loss: 0.0131, Val Acc: 1.0000
# [Attn] Epoch 89: Train Loss: 0.0136, Val Loss: 0.0129, Val Acc: 1.0000
# [Attn] Epoch 90: Train Loss: 0.0135, Val Loss: 0.0127, Val Acc: 1.0000
# [Attn] Epoch 91: Train Loss: 0.0132, Val Loss: 0.0125, Val Acc: 1.0000
# [Attn] Epoch 92: Train Loss: 0.0130, Val Loss: 0.0123, Val Acc: 1.0000
# [Attn] Epoch 93: Train Loss: 0.0128, Val Loss: 0.0121, Val Acc: 1.0000
# [Attn] Epoch 94: Train Loss: 0.0126, Val Loss: 0.0119, Val Acc: 1.0000
# [Attn] Epoch 95: Train Loss: 0.0124, Val Loss: 0.0117, Val Acc: 1.0000
# [Attn] Epoch 96: Train Loss: 0.0122, Val Loss: 0.0115, Val Acc: 1.0000
# [Attn] Epoch 97: Train Loss: 0.0121, Val Loss: 0.0113, Val Acc: 1.0000
# [Attn] Epoch 98: Train Loss: 0.0118, Val Loss: 0.0112, Val Acc: 1.0000
# [Attn] Epoch 99: Train Loss: 0.0117, Val Loss: 0.0110, Val Acc: 1.0000
# [Attn] Epoch 100: Train Loss: 0.0115, Val Loss: 0.0109, Val Acc: 1.0000

# %%
# New dataset for Transformer which adds SOS token to target sequence
class TranslationDatasetTransformer(Dataset):
    def __init__(self, data, word_to_index):
        self.data = data
        self.word_to_index = word_to_index

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        eng, fr = self.data[idx]
        # Source: tokens with EOS token at the end
        input_tensor = torch.tensor([self.word_to_index[word] for word in eng.split()] + [EOS_token], dtype=torch.long)
        # Target: add SOS token at the beginning and EOS token at the end
        target_tensor = torch.tensor([SOS_token] + [self.word_to_index[word] for word in fr.split()] + [EOS_token], dtype=torch.long)
        return input_tensor, target_tensor

# Create the dataloader for Transformer using the new dataset
transformer_dataset = TranslationDatasetTransformer(english_to_french, word_to_index)
transformer_dataloader = DataLoader(transformer_dataset, batch_size=1, shuffle=True)

# %%
# Transformer-based Encoder-Decoder
# Define Positional Encoding module
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(dropout)
        pe = torch.zeros(max_len, d_model)  # (max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # (1, max_len, d_model)
        self.register_buffer('pe', pe)
    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return self.dropout(x)

# Define Transformer Encoder for source (English)
class EncoderTransformer(nn.Module):
    def __init__(self, input_dim, emb_dim, n_layers, nhead, hidden_dim, dropout=0.1):
        super(EncoderTransformer, self).__init__()
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.pos_encoder = PositionalEncoding(emb_dim, dropout)
        encoder_layer = nn.TransformerEncoderLayer(d_model=emb_dim, nhead=nhead,
                                                    dim_feedforward=hidden_dim, dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)
    def forward(self, src):
        # Scale embeddings and add positional encoding
        embedded = self.embedding(src) * math.sqrt(self.embedding.embedding_dim)
        embedded = self.pos_encoder(embedded)
        memory = self.transformer_encoder(embedded)
        return memory

# Define Transformer Decoder for target (French)
class DecoderTransformer(nn.Module):
    def __init__(self, output_dim, emb_dim, n_layers, nhead, hidden_dim, dropout=0.1):
        super(DecoderTransformer, self).__init__()
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.pos_encoder = PositionalEncoding(emb_dim, dropout)
        decoder_layer = nn.TransformerDecoderLayer(d_model=emb_dim, nhead=nhead,
                                                    dim_feedforward=hidden_dim, dropout=dropout, batch_first=True)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers=n_layers)
        self.fc_out = nn.Linear(emb_dim, output_dim)
    def forward(self, tgt, memory, tgt_mask=None):
        # Scale embeddings and add positional encoding
        embedded = self.embedding(tgt) * math.sqrt(self.embedding.embedding_dim)
        embedded = self.pos_encoder(embedded)
        output = self.transformer_decoder(embedded, memory, tgt_mask=tgt_mask)
        output = self.fc_out(output)
        return output

# Combine into a Transformer Seq2Seq model
class TransformerSeq2Seq(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, emb_dim, n_layers, nhead, hidden_dim, dropout=0.1):
        super(TransformerSeq2Seq, self).__init__()
        self.encoder = EncoderTransformer(src_vocab_size, emb_dim, n_layers, nhead, hidden_dim, dropout)
        self.decoder = DecoderTransformer(tgt_vocab_size, emb_dim, n_layers, nhead, hidden_dim, dropout)
    def forward(self, src, tgt, tgt_mask=None):
        memory = self.encoder(src)
        output = self.decoder(tgt, memory, tgt_mask=tgt_mask)
        return output

# Instantiate Transformer model
emb_dim = 128
n_layers_trans = 2
nhead_trans = 2
hidden_dim_trans = 256
transformer_model = TransformerSeq2Seq(input_size, output_size, emb_dim, n_layers_trans, nhead_trans, hidden_dim_trans, dropout=0.1).to(device)

# %%
# Training and evaluation functions for Transformer Seq2Seq
def generate_square_subsequent_mask(sz):
    mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def train_transformer(model, train_dataloader, eval_dataloader, optimizer, criterion, n_epochs=10):
    model.train()
    train_losses = []
    train_accuracies = []
    eval_losses = []
    eval_accuracies = []
    start_time = time.time()
    for epoch in range(n_epochs):
        total_loss = 0
        total_correct = 0
        total_tokens = 0
        for src, tgt in train_dataloader:
            src = src.to(device)  # Source: English
            tgt = tgt.to(device)  # Target: French (with SOS at beginning)
            optimizer.zero_grad()
            # Teacher forcing: use all tokens except last as input and shift target by one
            tgt_input = tgt[:, :-1]   # e.g., [SOS, word1, word2, ...]
            tgt_out = tgt[:, 1:]      # e.g., [word1, word2, ..., EOS]
            tgt_mask = generate_square_subsequent_mask(tgt_input.size(1)).to(device)
            output = model(src, tgt_input, tgt_mask=tgt_mask)
            # Reshape for loss calculation
            output = output.contiguous().view(-1, output.shape[-1])
            tgt_out = tgt_out.contiguous().view(-1)
            loss = criterion(output, tgt_out)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            # Compute predictions and token-level accuracy
            preds = output.argmax(dim=1)
            total_correct += (preds == tgt_out).sum().item()
            total_tokens += tgt_out.size(0)
        avg_train_loss = total_loss / len(train_dataloader)
        avg_train_acc = total_correct / total_tokens
        train_losses.append(avg_train_loss)
        train_accuracies.append(avg_train_acc)
        
        # Evaluate on validation (using eval_dataloader, which is the same in our case)
        model.eval()
        total_loss_val = 0
        total_correct_val = 0
        total_tokens_val = 0
        with torch.no_grad():
            for src, tgt in eval_dataloader:
                src = src.to(device)
                tgt = tgt.to(device)
                tgt_input = tgt[:, :-1]
                tgt_out = tgt[:, 1:]
                tgt_mask = generate_square_subsequent_mask(tgt_input.size(1)).to(device)
                output = model(src, tgt_input, tgt_mask=tgt_mask)
                output = output.contiguous().view(-1, output.shape[-1])
                tgt_out = tgt_out.contiguous().view(-1)
                loss_val = criterion(output, tgt_out)
                total_loss_val += loss_val.item()
                preds_val = output.argmax(dim=1)
                total_correct_val += (preds_val == tgt_out).sum().item()
                total_tokens_val += tgt_out.size(0)
        avg_eval_loss = total_loss_val / len(eval_dataloader)
        avg_eval_acc = total_correct_val / total_tokens_val
        eval_losses.append(avg_eval_loss)
        eval_accuracies.append(avg_eval_acc)
        print(f"[Transformer] Epoch {epoch+1}/{n_epochs}, Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_acc:.4f}, Eval Loss: {avg_eval_loss:.4f}, Eval Acc: {avg_eval_acc:.4f}")
        model.train()  # Switch back to training mode after evaluation
    total_time = time.time() - start_time
    print(f"Transformer training time: {total_time:.2f} seconds")
    return train_losses, train_accuracies, eval_losses, eval_accuracies, total_time

# %%
# Set up optimizer and loss for transformer
trans_optimizer = optim.Adam(transformer_model.parameters(), lr=0.001)
trans_criterion = nn.CrossEntropyLoss()
n_epochs_trans = 100

# Experimenting with Transformer configurations: 1, 2, and 4 layers; 2 and 4 heads
transformer_results = []
for n_layers in [1, 2, 4]:
    for n_heads in [2, 4]:
        print(f"Training Transformer with {n_layers} layers and {n_heads} heads")
        # Instantiate the Transformer model with the current configuration
        model_temp = TransformerSeq2Seq(input_size, output_size, emb_dim, n_layers, n_heads, hidden_dim_trans, dropout=0.1).to(device)
        optimizer_temp = optim.Adam(model_temp.parameters(), lr=0.001)
        # Train the model using the same dataloader for training and evaluation
        tr_loss, tr_acc, val_loss, val_acc, train_time = train_transformer(model_temp, transformer_dataloader, transformer_dataloader, optimizer_temp, trans_criterion, n_epochs=n_epochs_trans)
        # Store results in a dictionary
        transformer_results.append({
            'n_layers': n_layers,
            'n_heads': n_heads,
            'train_losses': tr_loss,
            'train_accuracies': tr_acc,
            'val_losses': val_loss,
            'val_accuracies': val_acc,
            'training_time': train_time,
            'model': model_temp
        })
        print(f"Config ({n_layers} layers, {n_heads} heads): Final Eval Loss: {val_loss[-1]:.4f}, Final Eval Acc: {val_acc[-1]:.4f}\n")
# Out:
# Training Transformer with 1 layers and 2 heads
# [Transformer] Epoch 1/100, Train Loss: 5.0345, Train Acc: 0.2273, Eval Loss: 3.6162, Eval Acc: 0.3333
# [Transformer] Epoch 2/100, Train Loss: 3.5655, Train Acc: 0.3333, Eval Loss: 2.6073, Eval Acc: 0.4009
# [Transformer] Epoch 3/100, Train Loss: 2.8639, Train Acc: 0.3779, Eval Loss: 1.9405, Eval Acc: 0.5791
# [Transformer] Epoch 4/100, Train Loss: 2.3103, Train Acc: 0.4547, Eval Loss: 1.4502, Eval Acc: 0.6851
# [Transformer] Epoch 5/100, Train Loss: 1.8164, Train Acc: 0.5607, Eval Loss: 1.0491, Eval Acc: 0.7972
# [Transformer] Epoch 6/100, Train Loss: 1.4222, Train Acc: 0.6682, Eval Loss: 0.7712, Eval Acc: 0.8402
# [Transformer] Epoch 7/100, Train Loss: 1.1400, Train Acc: 0.7035, Eval Loss: 0.5434, Eval Acc: 0.8771
# [Transformer] Epoch 8/100, Train Loss: 0.8998, Train Acc: 0.7573, Eval Loss: 0.3653, Eval Acc: 0.9278
# [Transformer] Epoch 9/100, Train Loss: 0.6401, Train Acc: 0.8418, Eval Loss: 0.2544, Eval Acc: 0.9647
# [Transformer] Epoch 10/100, Train Loss: 0.4840, Train Acc: 0.8940, Eval Loss: 0.1481, Eval Acc: 0.9831
# [Transformer] Epoch 11/100, Train Loss: 0.4164, Train Acc: 0.9002, Eval Loss: 0.1427, Eval Acc: 0.9754
# [Transformer] Epoch 12/100, Train Loss: 0.3273, Train Acc: 0.9201, Eval Loss: 0.1010, Eval Acc: 0.9846
# [Transformer] Epoch 13/100, Train Loss: 0.2851, Train Acc: 0.9370, Eval Loss: 0.0655, Eval Acc: 0.9939
# [Transformer] Epoch 14/100, Train Loss: 0.2770, Train Acc: 0.9370, Eval Loss: 0.0989, Eval Acc: 0.9800
# [Transformer] Epoch 15/100, Train Loss: 0.4045, Train Acc: 0.9078, Eval Loss: 0.3041, Eval Acc: 0.9109
# [Transformer] Epoch 16/100, Train Loss: 0.3875, Train Acc: 0.9063, Eval Loss: 0.0863, Eval Acc: 0.9831
# [Transformer] Epoch 17/100, Train Loss: 0.2577, Train Acc: 0.9370, Eval Loss: 0.0893, Eval Acc: 0.9708
# [Transformer] Epoch 18/100, Train Loss: 0.2093, Train Acc: 0.9570, Eval Loss: 0.0551, Eval Acc: 0.9877
# [Transformer] Epoch 19/100, Train Loss: 0.1620, Train Acc: 0.9724, Eval Loss: 0.0251, Eval Acc: 0.9954
# [Transformer] Epoch 20/100, Train Loss: 0.1512, Train Acc: 0.9601, Eval Loss: 0.0244, Eval Acc: 0.9954
# [Transformer] Epoch 21/100, Train Loss: 0.1962, Train Acc: 0.9432, Eval Loss: 0.0607, Eval Acc: 0.9877
# [Transformer] Epoch 22/100, Train Loss: 0.2768, Train Acc: 0.9309, Eval Loss: 0.0816, Eval Acc: 0.9785
# [Transformer] Epoch 23/100, Train Loss: 0.2738, Train Acc: 0.9278, Eval Loss: 0.0564, Eval Acc: 0.9877
# [Transformer] Epoch 24/100, Train Loss: 0.3111, Train Acc: 0.9247, Eval Loss: 0.0620, Eval Acc: 0.9831
# [Transformer] Epoch 25/100, Train Loss: 0.2341, Train Acc: 0.9370, Eval Loss: 0.0534, Eval Acc: 0.9862
# [Transformer] Epoch 26/100, Train Loss: 0.3160, Train Acc: 0.9263, Eval Loss: 0.0928, Eval Acc: 0.9846
# [Transformer] Epoch 27/100, Train Loss: 0.2230, Train Acc: 0.9462, Eval Loss: 0.0680, Eval Acc: 0.9877
# [Transformer] Epoch 28/100, Train Loss: 0.2059, Train Acc: 0.9401, Eval Loss: 0.0510, Eval Acc: 0.9877
# [Transformer] Epoch 29/100, Train Loss: 0.1933, Train Acc: 0.9601, Eval Loss: 0.0363, Eval Acc: 0.9892
# [Transformer] Epoch 30/100, Train Loss: 0.2004, Train Acc: 0.9432, Eval Loss: 0.0459, Eval Acc: 0.9908
# [Transformer] Epoch 31/100, Train Loss: 0.1843, Train Acc: 0.9539, Eval Loss: 0.0624, Eval Acc: 0.9831
# [Transformer] Epoch 32/100, Train Loss: 0.2086, Train Acc: 0.9370, Eval Loss: 0.0330, Eval Acc: 0.9923
# [Transformer] Epoch 33/100, Train Loss: 0.2177, Train Acc: 0.9386, Eval Loss: 0.0745, Eval Acc: 0.9770
# [Transformer] Epoch 34/100, Train Loss: 0.1465, Train Acc: 0.9631, Eval Loss: 0.0145, Eval Acc: 0.9954
# [Transformer] Epoch 35/100, Train Loss: 0.1243, Train Acc: 0.9677, Eval Loss: 0.0236, Eval Acc: 0.9923
# [Transformer] Epoch 36/100, Train Loss: 0.1086, Train Acc: 0.9693, Eval Loss: 0.0265, Eval Acc: 0.9877
# [Transformer] Epoch 37/100, Train Loss: 0.1434, Train Acc: 0.9631, Eval Loss: 0.0464, Eval Acc: 0.9908
# [Transformer] Epoch 38/100, Train Loss: 0.2116, Train Acc: 0.9416, Eval Loss: 0.0711, Eval Acc: 0.9816
# [Transformer] Epoch 39/100, Train Loss: 0.3430, Train Acc: 0.9109, Eval Loss: 0.0292, Eval Acc: 0.9939
# [Transformer] Epoch 40/100, Train Loss: 0.1817, Train Acc: 0.9508, Eval Loss: 0.0498, Eval Acc: 0.9831
# [Transformer] Epoch 41/100, Train Loss: 0.1965, Train Acc: 0.9478, Eval Loss: 0.0388, Eval Acc: 0.9892
# [Transformer] Epoch 42/100, Train Loss: 0.1624, Train Acc: 0.9601, Eval Loss: 0.0334, Eval Acc: 0.9923
# [Transformer] Epoch 43/100, Train Loss: 0.1727, Train Acc: 0.9508, Eval Loss: 0.0811, Eval Acc: 0.9800
# [Transformer] Epoch 44/100, Train Loss: 0.1771, Train Acc: 0.9478, Eval Loss: 0.0300, Eval Acc: 0.9908
# [Transformer] Epoch 45/100, Train Loss: 0.1611, Train Acc: 0.9570, Eval Loss: 0.0209, Eval Acc: 0.9939
# [Transformer] Epoch 46/100, Train Loss: 0.1200, Train Acc: 0.9708, Eval Loss: 0.0143, Eval Acc: 0.9969
# [Transformer] Epoch 47/100, Train Loss: 0.1351, Train Acc: 0.9570, Eval Loss: 0.0189, Eval Acc: 0.9954
# [Transformer] Epoch 48/100, Train Loss: 0.1719, Train Acc: 0.9493, Eval Loss: 0.0770, Eval Acc: 0.9831
# [Transformer] Epoch 49/100, Train Loss: 0.1951, Train Acc: 0.9493, Eval Loss: 0.0271, Eval Acc: 0.9892
# [Transformer] Epoch 50/100, Train Loss: 0.1568, Train Acc: 0.9508, Eval Loss: 0.0184, Eval Acc: 0.9923
# [Transformer] Epoch 51/100, Train Loss: 0.2206, Train Acc: 0.9478, Eval Loss: 0.0189, Eval Acc: 0.9969
# [Transformer] Epoch 52/100, Train Loss: 0.1634, Train Acc: 0.9570, Eval Loss: 0.0378, Eval Acc: 0.9892
# [Transformer] Epoch 53/100, Train Loss: 0.1558, Train Acc: 0.9570, Eval Loss: 0.0339, Eval Acc: 0.9862
# [Transformer] Epoch 54/100, Train Loss: 0.1244, Train Acc: 0.9601, Eval Loss: 0.0206, Eval Acc: 0.9939
# [Transformer] Epoch 55/100, Train Loss: 0.1490, Train Acc: 0.9601, Eval Loss: 0.0896, Eval Acc: 0.9800
# [Transformer] Epoch 56/100, Train Loss: 0.1803, Train Acc: 0.9447, Eval Loss: 0.0162, Eval Acc: 0.9954
# [Transformer] Epoch 57/100, Train Loss: 0.1627, Train Acc: 0.9416, Eval Loss: 0.0194, Eval Acc: 0.9939
# [Transformer] Epoch 58/100, Train Loss: 0.1444, Train Acc: 0.9616, Eval Loss: 0.0143, Eval Acc: 0.9954
# [Transformer] Epoch 59/100, Train Loss: 0.1844, Train Acc: 0.9401, Eval Loss: 0.0239, Eval Acc: 0.9923
# [Transformer] Epoch 60/100, Train Loss: 0.1662, Train Acc: 0.9555, Eval Loss: 0.0580, Eval Acc: 0.9892
# [Transformer] Epoch 61/100, Train Loss: 0.2109, Train Acc: 0.9386, Eval Loss: 0.0369, Eval Acc: 0.9908
# [Transformer] Epoch 62/100, Train Loss: 0.2103, Train Acc: 0.9478, Eval Loss: 0.0415, Eval Acc: 0.9862
# [Transformer] Epoch 63/100, Train Loss: 0.1383, Train Acc: 0.9539, Eval Loss: 0.0412, Eval Acc: 0.9908
# [Transformer] Epoch 64/100, Train Loss: 0.1340, Train Acc: 0.9616, Eval Loss: 0.0293, Eval Acc: 0.9939
# [Transformer] Epoch 65/100, Train Loss: 0.1190, Train Acc: 0.9662, Eval Loss: 0.0097, Eval Acc: 0.9969
# [Transformer] Epoch 66/100, Train Loss: 0.1162, Train Acc: 0.9693, Eval Loss: 0.0136, Eval Acc: 0.9969
# [Transformer] Epoch 67/100, Train Loss: 0.1058, Train Acc: 0.9647, Eval Loss: 0.0326, Eval Acc: 0.9954
# [Transformer] Epoch 68/100, Train Loss: 0.1604, Train Acc: 0.9555, Eval Loss: 0.0433, Eval Acc: 0.9892
# [Transformer] Epoch 69/100, Train Loss: 0.1814, Train Acc: 0.9462, Eval Loss: 0.0569, Eval Acc: 0.9862
# [Transformer] Epoch 70/100, Train Loss: 0.2128, Train Acc: 0.9309, Eval Loss: 0.0525, Eval Acc: 0.9846
# [Transformer] Epoch 71/100, Train Loss: 0.1987, Train Acc: 0.9432, Eval Loss: 0.0397, Eval Acc: 0.9939
# [Transformer] Epoch 72/100, Train Loss: 0.1524, Train Acc: 0.9570, Eval Loss: 0.0305, Eval Acc: 0.9877
# [Transformer] Epoch 73/100, Train Loss: 0.2013, Train Acc: 0.9401, Eval Loss: 0.0238, Eval Acc: 0.9908
# [Transformer] Epoch 74/100, Train Loss: 0.2519, Train Acc: 0.9186, Eval Loss: 0.1001, Eval Acc: 0.9708
# [Transformer] Epoch 75/100, Train Loss: 0.2400, Train Acc: 0.9309, Eval Loss: 0.0739, Eval Acc: 0.9785
# [Transformer] Epoch 76/100, Train Loss: 0.1734, Train Acc: 0.9570, Eval Loss: 0.0205, Eval Acc: 0.9939
# [Transformer] Epoch 77/100, Train Loss: 0.1165, Train Acc: 0.9631, Eval Loss: 0.0190, Eval Acc: 0.9939
# [Transformer] Epoch 78/100, Train Loss: 0.1041, Train Acc: 0.9724, Eval Loss: 0.0081, Eval Acc: 0.9969
# [Transformer] Epoch 79/100, Train Loss: 0.0686, Train Acc: 0.9785, Eval Loss: 0.0081, Eval Acc: 0.9969
# [Transformer] Epoch 80/100, Train Loss: 0.0573, Train Acc: 0.9846, Eval Loss: 0.0133, Eval Acc: 0.9954
# [Transformer] Epoch 81/100, Train Loss: 0.0724, Train Acc: 0.9785, Eval Loss: 0.0147, Eval Acc: 0.9954
# [Transformer] Epoch 82/100, Train Loss: 0.0848, Train Acc: 0.9754, Eval Loss: 0.0087, Eval Acc: 0.9969
# [Transformer] Epoch 83/100, Train Loss: 0.1190, Train Acc: 0.9724, Eval Loss: 0.0148, Eval Acc: 0.9954
# [Transformer] Epoch 84/100, Train Loss: 0.1029, Train Acc: 0.9724, Eval Loss: 0.0438, Eval Acc: 0.9939
# [Transformer] Epoch 85/100, Train Loss: 0.1151, Train Acc: 0.9708, Eval Loss: 0.0089, Eval Acc: 0.9985
# [Transformer] Epoch 86/100, Train Loss: 0.1073, Train Acc: 0.9631, Eval Loss: 0.0338, Eval Acc: 0.9892
# [Transformer] Epoch 87/100, Train Loss: 0.1920, Train Acc: 0.9370, Eval Loss: 0.0814, Eval Acc: 0.9800
# [Transformer] Epoch 88/100, Train Loss: 0.3190, Train Acc: 0.9017, Eval Loss: 0.0550, Eval Acc: 0.9816
# [Transformer] Epoch 89/100, Train Loss: 0.2382, Train Acc: 0.9247, Eval Loss: 0.1119, Eval Acc: 0.9724
# [Transformer] Epoch 90/100, Train Loss: 0.2606, Train Acc: 0.9171, Eval Loss: 0.0612, Eval Acc: 0.9831
# [Transformer] Epoch 91/100, Train Loss: 0.2724, Train Acc: 0.9324, Eval Loss: 0.0369, Eval Acc: 0.9908
# [Transformer] Epoch 92/100, Train Loss: 0.2081, Train Acc: 0.9524, Eval Loss: 0.0146, Eval Acc: 0.9954
# [Transformer] Epoch 93/100, Train Loss: 0.0847, Train Acc: 0.9739, Eval Loss: 0.0123, Eval Acc: 0.9954
# [Transformer] Epoch 94/100, Train Loss: 0.0797, Train Acc: 0.9739, Eval Loss: 0.0116, Eval Acc: 0.9954
# [Transformer] Epoch 95/100, Train Loss: 0.0750, Train Acc: 0.9724, Eval Loss: 0.0129, Eval Acc: 0.9954
# [Transformer] Epoch 96/100, Train Loss: 0.0793, Train Acc: 0.9816, Eval Loss: 0.0035, Eval Acc: 0.9985
# [Transformer] Epoch 97/100, Train Loss: 0.1006, Train Acc: 0.9662, Eval Loss: 0.0310, Eval Acc: 0.9939
# [Transformer] Epoch 98/100, Train Loss: 0.1032, Train Acc: 0.9677, Eval Loss: 0.0462, Eval Acc: 0.9862
# [Transformer] Epoch 99/100, Train Loss: 0.1671, Train Acc: 0.9555, Eval Loss: 0.0510, Eval Acc: 0.9892
# [Transformer] Epoch 100/100, Train Loss: 0.1197, Train Acc: 0.9724, Eval Loss: 0.0237, Eval Acc: 0.9923
# Transformer training time: 39.07 seconds
# Config (1 layers, 2 heads): Final Eval Loss: 0.0237, Final Eval Acc: 0.9923
#
# Training Transformer with 1 layers and 4 heads
# [Transformer] Epoch 1/100, Train Loss: 5.0753, Train Acc: 0.2151, Eval Loss: 3.5120, Eval Acc: 0.3379
# [Transformer] Epoch 2/100, Train Loss: 3.5076, Train Acc: 0.3456, Eval Loss: 2.5743, Eval Acc: 0.4194
# [Transformer] Epoch 3/100, Train Loss: 2.7393, Train Acc: 0.4040, Eval Loss: 1.8142, Eval Acc: 0.6375
# [Transformer] Epoch 4/100, Train Loss: 2.1320, Train Acc: 0.5038, Eval Loss: 1.3092, Eval Acc: 0.6989
# [Transformer] Epoch 5/100, Train Loss: 1.5930, Train Acc: 0.6083, Eval Loss: 0.7991, Eval Acc: 0.8525
# [Transformer] Epoch 6/100, Train Loss: 1.2561, Train Acc: 0.6759, Eval Loss: 0.5403, Eval Acc: 0.9263
# [Transformer] Epoch 7/100, Train Loss: 0.8672, Train Acc: 0.7988, Eval Loss: 0.3119, Eval Acc: 0.9662
# [Transformer] Epoch 8/100, Train Loss: 0.6164, Train Acc: 0.8679, Eval Loss: 0.2036, Eval Acc: 0.9785
# [Transformer] Epoch 9/100, Train Loss: 0.4418, Train Acc: 0.9124, Eval Loss: 0.1365, Eval Acc: 0.9831
# [Transformer] Epoch 10/100, Train Loss: 0.3381, Train Acc: 0.9432, Eval Loss: 0.1041, Eval Acc: 0.9846
# [Transformer] Epoch 11/100, Train Loss: 0.2523, Train Acc: 0.9555, Eval Loss: 0.0585, Eval Acc: 0.9954
# [Transformer] Epoch 12/100, Train Loss: 0.2179, Train Acc: 0.9616, Eval Loss: 0.0621, Eval Acc: 0.9862
# [Transformer] Epoch 13/100, Train Loss: 0.1984, Train Acc: 0.9570, Eval Loss: 0.0408, Eval Acc: 0.9954
# [Transformer] Epoch 14/100, Train Loss: 0.1301, Train Acc: 0.9846, Eval Loss: 0.0206, Eval Acc: 0.9969
# [Transformer] Epoch 15/100, Train Loss: 0.1035, Train Acc: 0.9770, Eval Loss: 0.0327, Eval Acc: 0.9969
# [Transformer] Epoch 16/100, Train Loss: 0.1165, Train Acc: 0.9846, Eval Loss: 0.0261, Eval Acc: 0.9939
# [Transformer] Epoch 17/100, Train Loss: 0.0933, Train Acc: 0.9800, Eval Loss: 0.0401, Eval Acc: 0.9923
# [Transformer] Epoch 18/100, Train Loss: 0.1663, Train Acc: 0.9662, Eval Loss: 0.0293, Eval Acc: 0.9923
# [Transformer] Epoch 19/100, Train Loss: 0.1223, Train Acc: 0.9708, Eval Loss: 0.0313, Eval Acc: 0.9908
# [Transformer] Epoch 20/100, Train Loss: 0.2790, Train Acc: 0.9201, Eval Loss: 0.0926, Eval Acc: 0.9846
# [Transformer] Epoch 21/100, Train Loss: 0.2548, Train Acc: 0.9386, Eval Loss: 0.1027, Eval Acc: 0.9647
# [Transformer] Epoch 22/100, Train Loss: 0.3225, Train Acc: 0.9171, Eval Loss: 0.0581, Eval Acc: 0.9846
# [Transformer] Epoch 23/100, Train Loss: 0.2059, Train Acc: 0.9447, Eval Loss: 0.0512, Eval Acc: 0.9877
# [Transformer] Epoch 24/100, Train Loss: 0.1608, Train Acc: 0.9493, Eval Loss: 0.0487, Eval Acc: 0.9892
# [Transformer] Epoch 25/100, Train Loss: 0.1482, Train Acc: 0.9601, Eval Loss: 0.0516, Eval Acc: 0.9892
# [Transformer] Epoch 26/100, Train Loss: 0.1366, Train Acc: 0.9708, Eval Loss: 0.0225, Eval Acc: 0.9892
# [Transformer] Epoch 27/100, Train Loss: 0.1641, Train Acc: 0.9539, Eval Loss: 0.0428, Eval Acc: 0.9908
# [Transformer] Epoch 28/100, Train Loss: 0.1273, Train Acc: 0.9647, Eval Loss: 0.0454, Eval Acc: 0.9892
# [Transformer] Epoch 29/100, Train Loss: 0.1250, Train Acc: 0.9677, Eval Loss: 0.0184, Eval Acc: 0.9923
# [Transformer] Epoch 30/100, Train Loss: 0.1408, Train Acc: 0.9631, Eval Loss: 0.0358, Eval Acc: 0.9862
# [Transformer] Epoch 31/100, Train Loss: 0.1126, Train Acc: 0.9647, Eval Loss: 0.0262, Eval Acc: 0.9908
# [Transformer] Epoch 32/100, Train Loss: 0.1081, Train Acc: 0.9754, Eval Loss: 0.0206, Eval Acc: 0.9923
# [Transformer] Epoch 33/100, Train Loss: 0.0807, Train Acc: 0.9754, Eval Loss: 0.0217, Eval Acc: 0.9923
# [Transformer] Epoch 34/100, Train Loss: 0.1054, Train Acc: 0.9724, Eval Loss: 0.0291, Eval Acc: 0.9892
# [Transformer] Epoch 35/100, Train Loss: 0.1430, Train Acc: 0.9585, Eval Loss: 0.0137, Eval Acc: 0.9985
# [Transformer] Epoch 36/100, Train Loss: 0.1128, Train Acc: 0.9585, Eval Loss: 0.0243, Eval Acc: 0.9923
# [Transformer] Epoch 37/100, Train Loss: 0.1718, Train Acc: 0.9601, Eval Loss: 0.0235, Eval Acc: 0.9908
# [Transformer] Epoch 38/100, Train Loss: 0.1089, Train Acc: 0.9708, Eval Loss: 0.0441, Eval Acc: 0.9923
# [Transformer] Epoch 39/100, Train Loss: 0.1503, Train Acc: 0.9508, Eval Loss: 0.0519, Eval Acc: 0.9908
# [Transformer] Epoch 40/100, Train Loss: 0.1465, Train Acc: 0.9662, Eval Loss: 0.0121, Eval Acc: 0.9969
# [Transformer] Epoch 41/100, Train Loss: 0.0969, Train Acc: 0.9677, Eval Loss: 0.0254, Eval Acc: 0.9908
# [Transformer] Epoch 42/100, Train Loss: 0.1508, Train Acc: 0.9524, Eval Loss: 0.0310, Eval Acc: 0.9877
# [Transformer] Epoch 43/100, Train Loss: 0.1433, Train Acc: 0.9662, Eval Loss: 0.0211, Eval Acc: 0.9923
# [Transformer] Epoch 44/100, Train Loss: 0.0819, Train Acc: 0.9739, Eval Loss: 0.0146, Eval Acc: 0.9954
# [Transformer] Epoch 45/100, Train Loss: 0.0959, Train Acc: 0.9754, Eval Loss: 0.0340, Eval Acc: 0.9892
# [Transformer] Epoch 46/100, Train Loss: 0.1346, Train Acc: 0.9708, Eval Loss: 0.0332, Eval Acc: 0.9923
# [Transformer] Epoch 47/100, Train Loss: 0.1030, Train Acc: 0.9693, Eval Loss: 0.0112, Eval Acc: 0.9969
# [Transformer] Epoch 48/100, Train Loss: 0.0459, Train Acc: 0.9877, Eval Loss: 0.0048, Eval Acc: 0.9985
# [Transformer] Epoch 49/100, Train Loss: 0.0852, Train Acc: 0.9785, Eval Loss: 0.0198, Eval Acc: 0.9939
# [Transformer] Epoch 50/100, Train Loss: 0.0925, Train Acc: 0.9770, Eval Loss: 0.0093, Eval Acc: 0.9969
# [Transformer] Epoch 51/100, Train Loss: 0.0824, Train Acc: 0.9831, Eval Loss: 0.0136, Eval Acc: 0.9954
# [Transformer] Epoch 52/100, Train Loss: 0.1064, Train Acc: 0.9708, Eval Loss: 0.0658, Eval Acc: 0.9831
# [Transformer] Epoch 53/100, Train Loss: 0.1311, Train Acc: 0.9631, Eval Loss: 0.0153, Eval Acc: 0.9969
# [Transformer] Epoch 54/100, Train Loss: 0.1264, Train Acc: 0.9601, Eval Loss: 0.0478, Eval Acc: 0.9831
# [Transformer] Epoch 55/100, Train Loss: 0.1557, Train Acc: 0.9462, Eval Loss: 0.0180, Eval Acc: 0.9954
# [Transformer] Epoch 56/100, Train Loss: 0.1659, Train Acc: 0.9416, Eval Loss: 0.0607, Eval Acc: 0.9862
# [Transformer] Epoch 57/100, Train Loss: 0.1340, Train Acc: 0.9631, Eval Loss: 0.0078, Eval Acc: 0.9969
# [Transformer] Epoch 58/100, Train Loss: 0.0977, Train Acc: 0.9677, Eval Loss: 0.0338, Eval Acc: 0.9908
# [Transformer] Epoch 59/100, Train Loss: 0.1145, Train Acc: 0.9708, Eval Loss: 0.0050, Eval Acc: 0.9985
# [Transformer] Epoch 60/100, Train Loss: 0.0642, Train Acc: 0.9816, Eval Loss: 0.0149, Eval Acc: 0.9969
# [Transformer] Epoch 61/100, Train Loss: 0.0935, Train Acc: 0.9708, Eval Loss: 0.0118, Eval Acc: 0.9969
# [Transformer] Epoch 62/100, Train Loss: 0.0814, Train Acc: 0.9785, Eval Loss: 0.0118, Eval Acc: 0.9969
# [Transformer] Epoch 63/100, Train Loss: 0.0596, Train Acc: 0.9800, Eval Loss: 0.0178, Eval Acc: 0.9908
# [Transformer] Epoch 64/100, Train Loss: 0.0910, Train Acc: 0.9754, Eval Loss: 0.0480, Eval Acc: 0.9892
# [Transformer] Epoch 65/100, Train Loss: 0.1463, Train Acc: 0.9616, Eval Loss: 0.0562, Eval Acc: 0.9862
# [Transformer] Epoch 66/100, Train Loss: 0.0922, Train Acc: 0.9739, Eval Loss: 0.0104, Eval Acc: 0.9954
# [Transformer] Epoch 67/100, Train Loss: 0.1182, Train Acc: 0.9647, Eval Loss: 0.0137, Eval Acc: 0.9954
# [Transformer] Epoch 68/100, Train Loss: 0.1472, Train Acc: 0.9585, Eval Loss: 0.0622, Eval Acc: 0.9800
# [Transformer] Epoch 69/100, Train Loss: 0.1132, Train Acc: 0.9677, Eval Loss: 0.0514, Eval Acc: 0.9892
# [Transformer] Epoch 70/100, Train Loss: 0.1226, Train Acc: 0.9631, Eval Loss: 0.0083, Eval Acc: 0.9954
# [Transformer] Epoch 71/100, Train Loss: 0.1343, Train Acc: 0.9585, Eval Loss: 0.0736, Eval Acc: 0.9785
# [Transformer] Epoch 72/100, Train Loss: 0.1060, Train Acc: 0.9693, Eval Loss: 0.0125, Eval Acc: 0.9985
# [Transformer] Epoch 73/100, Train Loss: 0.0810, Train Acc: 0.9754, Eval Loss: 0.0116, Eval Acc: 0.9954
# [Transformer] Epoch 74/100, Train Loss: 0.1049, Train Acc: 0.9739, Eval Loss: 0.0226, Eval Acc: 0.9923
# [Transformer] Epoch 75/100, Train Loss: 0.1244, Train Acc: 0.9677, Eval Loss: 0.0242, Eval Acc: 0.9908
# [Transformer] Epoch 76/100, Train Loss: 0.1342, Train Acc: 0.9585, Eval Loss: 0.0156, Eval Acc: 0.9923
# [Transformer] Epoch 77/100, Train Loss: 0.1280, Train Acc: 0.9570, Eval Loss: 0.0153, Eval Acc: 0.9939
# [Transformer] Epoch 78/100, Train Loss: 0.0688, Train Acc: 0.9800, Eval Loss: 0.0107, Eval Acc: 0.9939
# [Transformer] Epoch 79/100, Train Loss: 0.0841, Train Acc: 0.9677, Eval Loss: 0.0414, Eval Acc: 0.9877
# [Transformer] Epoch 80/100, Train Loss: 0.0866, Train Acc: 0.9724, Eval Loss: 0.0140, Eval Acc: 0.9969
# [Transformer] Epoch 81/100, Train Loss: 0.0902, Train Acc: 0.9724, Eval Loss: 0.0174, Eval Acc: 0.9939
# [Transformer] Epoch 82/100, Train Loss: 0.0688, Train Acc: 0.9770, Eval Loss: 0.0254, Eval Acc: 0.9923
# [Transformer] Epoch 83/100, Train Loss: 0.1375, Train Acc: 0.9616, Eval Loss: 0.0058, Eval Acc: 0.9985
# [Transformer] Epoch 84/100, Train Loss: 0.0725, Train Acc: 0.9785, Eval Loss: 0.0206, Eval Acc: 0.9908
# [Transformer] Epoch 85/100, Train Loss: 0.0555, Train Acc: 0.9862, Eval Loss: 0.0245, Eval Acc: 0.9969
# [Transformer] Epoch 86/100, Train Loss: 0.0714, Train Acc: 0.9862, Eval Loss: 0.0246, Eval Acc: 0.9939
# [Transformer] Epoch 87/100, Train Loss: 0.0477, Train Acc: 0.9862, Eval Loss: 0.0024, Eval Acc: 1.0000
# [Transformer] Epoch 88/100, Train Loss: 0.0560, Train Acc: 0.9862, Eval Loss: 0.0035, Eval Acc: 0.9985
# [Transformer] Epoch 89/100, Train Loss: 0.0793, Train Acc: 0.9770, Eval Loss: 0.0514, Eval Acc: 0.9908
# [Transformer] Epoch 90/100, Train Loss: 0.2043, Train Acc: 0.9447, Eval Loss: 0.0657, Eval Acc: 0.9785
# [Transformer] Epoch 91/100, Train Loss: 0.1708, Train Acc: 0.9401, Eval Loss: 0.0781, Eval Acc: 0.9770
# [Transformer] Epoch 92/100, Train Loss: 0.1797, Train Acc: 0.9508, Eval Loss: 0.0442, Eval Acc: 0.9862
# [Transformer] Epoch 93/100, Train Loss: 0.1531, Train Acc: 0.9555, Eval Loss: 0.0641, Eval Acc: 0.9862
# [Transformer] Epoch 94/100, Train Loss: 0.1495, Train Acc: 0.9555, Eval Loss: 0.0329, Eval Acc: 0.9908
# [Transformer] Epoch 95/100, Train Loss: 0.1190, Train Acc: 0.9693, Eval Loss: 0.0145, Eval Acc: 0.9969
# [Transformer] Epoch 96/100, Train Loss: 0.0712, Train Acc: 0.9831, Eval Loss: 0.0079, Eval Acc: 0.9985
# [Transformer] Epoch 97/100, Train Loss: 0.1009, Train Acc: 0.9754, Eval Loss: 0.0216, Eval Acc: 0.9923
# [Transformer] Epoch 98/100, Train Loss: 0.0673, Train Acc: 0.9724, Eval Loss: 0.0191, Eval Acc: 0.9939
# [Transformer] Epoch 99/100, Train Loss: 0.0640, Train Acc: 0.9816, Eval Loss: 0.0120, Eval Acc: 0.9939
# [Transformer] Epoch 100/100, Train Loss: 0.0431, Train Acc: 0.9862, Eval Loss: 0.0093, Eval Acc: 0.9985
# Transformer training time: 38.98 seconds
# Config (1 layers, 4 heads): Final Eval Loss: 0.0093, Final Eval Acc: 0.9985
#
# Training Transformer with 2 layers and 2 heads
# [Transformer] Epoch 1/100, Train Loss: 5.0081, Train Acc: 0.2412, Eval Loss: 3.9150, Eval Acc: 0.3287
# [Transformer] Epoch 2/100, Train Loss: 3.8471, Train Acc: 0.3210, Eval Loss: 3.1601, Eval Acc: 0.4132
# [Transformer] Epoch 3/100, Train Loss: 3.2264, Train Acc: 0.3641, Eval Loss: 2.4019, Eval Acc: 0.4347
# [Transformer] Epoch 4/100, Train Loss: 2.6352, Train Acc: 0.4117, Eval Loss: 1.9082, Eval Acc: 0.5300
# [Transformer] Epoch 5/100, Train Loss: 2.1735, Train Acc: 0.4962, Eval Loss: 1.3591, Eval Acc: 0.6866
# [Transformer] Epoch 6/100, Train Loss: 1.7083, Train Acc: 0.6114, Eval Loss: 0.9009, Eval Acc: 0.8233
# [Transformer] Epoch 7/100, Train Loss: 1.3007, Train Acc: 0.6575, Eval Loss: 0.5958, Eval Acc: 0.9155
# [Transformer] Epoch 8/100, Train Loss: 0.9176, Train Acc: 0.7865, Eval Loss: 0.3942, Eval Acc: 0.9416
# [Transformer] Epoch 9/100, Train Loss: 0.6663, Train Acc: 0.8648, Eval Loss: 0.2765, Eval Acc: 0.9616
# [Transformer] Epoch 10/100, Train Loss: 0.5149, Train Acc: 0.8817, Eval Loss: 0.1896, Eval Acc: 0.9677
# [Transformer] Epoch 11/100, Train Loss: 0.4599, Train Acc: 0.9063, Eval Loss: 0.1659, Eval Acc: 0.9739
# [Transformer] Epoch 12/100, Train Loss: 0.4263, Train Acc: 0.9140, Eval Loss: 0.2284, Eval Acc: 0.9555
# [Transformer] Epoch 13/100, Train Loss: 0.4611, Train Acc: 0.8894, Eval Loss: 0.1403, Eval Acc: 0.9724
# [Transformer] Epoch 14/100, Train Loss: 0.3143, Train Acc: 0.9355, Eval Loss: 0.1250, Eval Acc: 0.9739
# [Transformer] Epoch 15/100, Train Loss: 0.2908, Train Acc: 0.9324, Eval Loss: 0.0663, Eval Acc: 0.9923
# [Transformer] Epoch 16/100, Train Loss: 0.2531, Train Acc: 0.9447, Eval Loss: 0.0979, Eval Acc: 0.9770
# [Transformer] Epoch 17/100, Train Loss: 0.2588, Train Acc: 0.9416, Eval Loss: 0.0993, Eval Acc: 0.9816
# [Transformer] Epoch 18/100, Train Loss: 0.3116, Train Acc: 0.9293, Eval Loss: 0.1576, Eval Acc: 0.9662
# [Transformer] Epoch 19/100, Train Loss: 0.2286, Train Acc: 0.9478, Eval Loss: 0.1018, Eval Acc: 0.9785
# [Transformer] Epoch 20/100, Train Loss: 0.1953, Train Acc: 0.9462, Eval Loss: 0.0492, Eval Acc: 0.9923
# [Transformer] Epoch 21/100, Train Loss: 0.2190, Train Acc: 0.9432, Eval Loss: 0.0978, Eval Acc: 0.9785
# [Transformer] Epoch 22/100, Train Loss: 0.2262, Train Acc: 0.9432, Eval Loss: 0.0832, Eval Acc: 0.9754
# [Transformer] Epoch 23/100, Train Loss: 0.2102, Train Acc: 0.9508, Eval Loss: 0.0393, Eval Acc: 0.9877
# [Transformer] Epoch 24/100, Train Loss: 0.1521, Train Acc: 0.9631, Eval Loss: 0.0330, Eval Acc: 0.9939
# [Transformer] Epoch 25/100, Train Loss: 0.2349, Train Acc: 0.9370, Eval Loss: 0.1224, Eval Acc: 0.9631
# [Transformer] Epoch 26/100, Train Loss: 0.3051, Train Acc: 0.9247, Eval Loss: 0.0905, Eval Acc: 0.9785
# [Transformer] Epoch 27/100, Train Loss: 0.2835, Train Acc: 0.9186, Eval Loss: 0.1137, Eval Acc: 0.9693
# [Transformer] Epoch 28/100, Train Loss: 0.3230, Train Acc: 0.9124, Eval Loss: 0.2966, Eval Acc: 0.9309
# [Transformer] Epoch 29/100, Train Loss: 0.4046, Train Acc: 0.9017, Eval Loss: 0.0761, Eval Acc: 0.9800
# [Transformer] Epoch 30/100, Train Loss: 0.2323, Train Acc: 0.9462, Eval Loss: 0.0676, Eval Acc: 0.9800
# [Transformer] Epoch 31/100, Train Loss: 0.2959, Train Acc: 0.9217, Eval Loss: 0.1097, Eval Acc: 0.9647
# [Transformer] Epoch 32/100, Train Loss: 0.2658, Train Acc: 0.9355, Eval Loss: 0.0497, Eval Acc: 0.9908
# [Transformer] Epoch 33/100, Train Loss: 0.2018, Train Acc: 0.9585, Eval Loss: 0.0685, Eval Acc: 0.9770
# [Transformer] Epoch 34/100, Train Loss: 0.2159, Train Acc: 0.9432, Eval Loss: 0.0750, Eval Acc: 0.9846
# [Transformer] Epoch 35/100, Train Loss: 0.2154, Train Acc: 0.9386, Eval Loss: 0.0499, Eval Acc: 0.9862
# [Transformer] Epoch 36/100, Train Loss: 0.2285, Train Acc: 0.9524, Eval Loss: 0.1140, Eval Acc: 0.9693
# [Transformer] Epoch 37/100, Train Loss: 0.2701, Train Acc: 0.9186, Eval Loss: 0.0765, Eval Acc: 0.9739
# [Transformer] Epoch 38/100, Train Loss: 0.2294, Train Acc: 0.9217, Eval Loss: 0.0844, Eval Acc: 0.9831
# [Transformer] Epoch 39/100, Train Loss: 0.1791, Train Acc: 0.9585, Eval Loss: 0.0228, Eval Acc: 0.9954
# [Transformer] Epoch 40/100, Train Loss: 0.1576, Train Acc: 0.9493, Eval Loss: 0.0429, Eval Acc: 0.9877
# [Transformer] Epoch 41/100, Train Loss: 0.1311, Train Acc: 0.9693, Eval Loss: 0.0131, Eval Acc: 0.9969
# [Transformer] Epoch 42/100, Train Loss: 0.0817, Train Acc: 0.9800, Eval Loss: 0.0093, Eval Acc: 0.9969
# [Transformer] Epoch 43/100, Train Loss: 0.0928, Train Acc: 0.9708, Eval Loss: 0.0682, Eval Acc: 0.9831
# [Transformer] Epoch 44/100, Train Loss: 0.1290, Train Acc: 0.9631, Eval Loss: 0.0184, Eval Acc: 0.9939
# [Transformer] Epoch 45/100, Train Loss: 0.1067, Train Acc: 0.9708, Eval Loss: 0.1009, Eval Acc: 0.9754
# [Transformer] Epoch 46/100, Train Loss: 0.1718, Train Acc: 0.9585, Eval Loss: 0.0656, Eval Acc: 0.9785
# [Transformer] Epoch 47/100, Train Loss: 0.2933, Train Acc: 0.9217, Eval Loss: 0.0616, Eval Acc: 0.9862
# [Transformer] Epoch 48/100, Train Loss: 0.2479, Train Acc: 0.9140, Eval Loss: 0.2285, Eval Acc: 0.9324
# [Transformer] Epoch 49/100, Train Loss: 0.3803, Train Acc: 0.8894, Eval Loss: 0.1561, Eval Acc: 0.9539
# [Transformer] Epoch 50/100, Train Loss: 0.3936, Train Acc: 0.8802, Eval Loss: 0.2031, Eval Acc: 0.9416
# [Transformer] Epoch 51/100, Train Loss: 0.2494, Train Acc: 0.9339, Eval Loss: 0.0425, Eval Acc: 0.9862
# [Transformer] Epoch 52/100, Train Loss: 0.1982, Train Acc: 0.9432, Eval Loss: 0.0268, Eval Acc: 0.9923
# [Transformer] Epoch 53/100, Train Loss: 0.1213, Train Acc: 0.9677, Eval Loss: 0.0353, Eval Acc: 0.9923
# [Transformer] Epoch 54/100, Train Loss: 0.1474, Train Acc: 0.9708, Eval Loss: 0.0559, Eval Acc: 0.9877
# [Transformer] Epoch 55/100, Train Loss: 0.1271, Train Acc: 0.9677, Eval Loss: 0.0263, Eval Acc: 0.9923
# [Transformer] Epoch 56/100, Train Loss: 0.0894, Train Acc: 0.9739, Eval Loss: 0.0170, Eval Acc: 0.9923
# [Transformer] Epoch 57/100, Train Loss: 0.0664, Train Acc: 0.9816, Eval Loss: 0.0280, Eval Acc: 0.9939
# [Transformer] Epoch 58/100, Train Loss: 0.1662, Train Acc: 0.9493, Eval Loss: 0.0390, Eval Acc: 0.9908
# [Transformer] Epoch 59/100, Train Loss: 0.1397, Train Acc: 0.9601, Eval Loss: 0.0360, Eval Acc: 0.9939
# [Transformer] Epoch 60/100, Train Loss: 0.1740, Train Acc: 0.9555, Eval Loss: 0.0375, Eval Acc: 0.9892
# [Transformer] Epoch 61/100, Train Loss: 0.1519, Train Acc: 0.9539, Eval Loss: 0.0904, Eval Acc: 0.9785
# [Transformer] Epoch 62/100, Train Loss: 0.2681, Train Acc: 0.9232, Eval Loss: 0.0675, Eval Acc: 0.9831
# [Transformer] Epoch 63/100, Train Loss: 0.3068, Train Acc: 0.9232, Eval Loss: 0.0596, Eval Acc: 0.9800
# [Transformer] Epoch 64/100, Train Loss: 0.1814, Train Acc: 0.9447, Eval Loss: 0.0449, Eval Acc: 0.9846
# [Transformer] Epoch 65/100, Train Loss: 0.2506, Train Acc: 0.9201, Eval Loss: 0.1143, Eval Acc: 0.9677
# [Transformer] Epoch 66/100, Train Loss: 0.3081, Train Acc: 0.9109, Eval Loss: 0.1601, Eval Acc: 0.9601
# [Transformer] Epoch 67/100, Train Loss: 0.3407, Train Acc: 0.8986, Eval Loss: 0.1195, Eval Acc: 0.9662
# [Transformer] Epoch 68/100, Train Loss: 0.3888, Train Acc: 0.8986, Eval Loss: 0.0886, Eval Acc: 0.9708
# [Transformer] Epoch 69/100, Train Loss: 0.2694, Train Acc: 0.9140, Eval Loss: 0.0543, Eval Acc: 0.9846
# [Transformer] Epoch 70/100, Train Loss: 0.1633, Train Acc: 0.9447, Eval Loss: 0.0178, Eval Acc: 0.9939
# [Transformer] Epoch 71/100, Train Loss: 0.1234, Train Acc: 0.9662, Eval Loss: 0.0277, Eval Acc: 0.9954
# [Transformer] Epoch 72/100, Train Loss: 0.0973, Train Acc: 0.9724, Eval Loss: 0.0530, Eval Acc: 0.9877
# [Transformer] Epoch 73/100, Train Loss: 0.1350, Train Acc: 0.9570, Eval Loss: 0.0205, Eval Acc: 0.9923
# [Transformer] Epoch 74/100, Train Loss: 0.1448, Train Acc: 0.9570, Eval Loss: 0.0084, Eval Acc: 1.0000
# [Transformer] Epoch 75/100, Train Loss: 0.0992, Train Acc: 0.9708, Eval Loss: 0.0130, Eval Acc: 0.9954
# [Transformer] Epoch 76/100, Train Loss: 0.0598, Train Acc: 0.9816, Eval Loss: 0.0139, Eval Acc: 0.9939
# [Transformer] Epoch 77/100, Train Loss: 0.0755, Train Acc: 0.9754, Eval Loss: 0.0193, Eval Acc: 0.9954
# [Transformer] Epoch 78/100, Train Loss: 0.0922, Train Acc: 0.9708, Eval Loss: 0.0185, Eval Acc: 0.9969
# [Transformer] Epoch 79/100, Train Loss: 0.1337, Train Acc: 0.9647, Eval Loss: 0.0226, Eval Acc: 0.9908
# [Transformer] Epoch 80/100, Train Loss: 0.0775, Train Acc: 0.9785, Eval Loss: 0.0567, Eval Acc: 0.9862
# [Transformer] Epoch 81/100, Train Loss: 0.2070, Train Acc: 0.9508, Eval Loss: 0.0415, Eval Acc: 0.9816
# [Transformer] Epoch 82/100, Train Loss: 0.3138, Train Acc: 0.9063, Eval Loss: 0.1274, Eval Acc: 0.9677
# [Transformer] Epoch 83/100, Train Loss: 0.4107, Train Acc: 0.8833, Eval Loss: 0.0990, Eval Acc: 0.9631
# [Transformer] Epoch 84/100, Train Loss: 0.3018, Train Acc: 0.9140, Eval Loss: 0.0619, Eval Acc: 0.9831
# [Transformer] Epoch 85/100, Train Loss: 0.2061, Train Acc: 0.9401, Eval Loss: 0.0718, Eval Acc: 0.9800
# [Transformer] Epoch 86/100, Train Loss: 0.2973, Train Acc: 0.9278, Eval Loss: 0.2090, Eval Acc: 0.9539
# [Transformer] Epoch 87/100, Train Loss: 0.2413, Train Acc: 0.9432, Eval Loss: 0.0728, Eval Acc: 0.9739
# [Transformer] Epoch 88/100, Train Loss: 0.3130, Train Acc: 0.8986, Eval Loss: 0.1213, Eval Acc: 0.9601
# [Transformer] Epoch 89/100, Train Loss: 0.1700, Train Acc: 0.9508, Eval Loss: 0.0484, Eval Acc: 0.9939
# [Transformer] Epoch 90/100, Train Loss: 0.1728, Train Acc: 0.9493, Eval Loss: 0.0439, Eval Acc: 0.9877
# [Transformer] Epoch 91/100, Train Loss: 0.1132, Train Acc: 0.9693, Eval Loss: 0.0198, Eval Acc: 0.9908
# [Transformer] Epoch 92/100, Train Loss: 0.0824, Train Acc: 0.9724, Eval Loss: 0.0131, Eval Acc: 0.9954
# [Transformer] Epoch 93/100, Train Loss: 0.1124, Train Acc: 0.9647, Eval Loss: 0.0411, Eval Acc: 0.9908
# [Transformer] Epoch 94/100, Train Loss: 0.1353, Train Acc: 0.9508, Eval Loss: 0.0114, Eval Acc: 0.9985
# [Transformer] Epoch 95/100, Train Loss: 0.1093, Train Acc: 0.9693, Eval Loss: 0.0249, Eval Acc: 0.9939
# [Transformer] Epoch 96/100, Train Loss: 0.1547, Train Acc: 0.9539, Eval Loss: 0.0605, Eval Acc: 0.9923
# [Transformer] Epoch 97/100, Train Loss: 0.2704, Train Acc: 0.9247, Eval Loss: 0.0514, Eval Acc: 0.9831
# [Transformer] Epoch 98/100, Train Loss: 0.1827, Train Acc: 0.9493, Eval Loss: 0.0393, Eval Acc: 0.9892
# [Transformer] Epoch 99/100, Train Loss: 0.1597, Train Acc: 0.9539, Eval Loss: 0.0250, Eval Acc: 0.9954
# [Transformer] Epoch 100/100, Train Loss: 0.2211, Train Acc: 0.9355, Eval Loss: 0.0754, Eval Acc: 0.9831
# Transformer training time: 63.52 seconds
# Config (2 layers, 2 heads): Final Eval Loss: 0.0754, Final Eval Acc: 0.9831
#
# Training Transformer with 2 layers and 4 heads
# [Transformer] Epoch 1/100, Train Loss: 5.0735, Train Acc: 0.2166, Eval Loss: 3.8922, Eval Acc: 0.2903
# [Transformer] Epoch 2/100, Train Loss: 3.9545, Train Acc: 0.3118, Eval Loss: 3.0201, Eval Acc: 0.3748
# [Transformer] Epoch 3/100, Train Loss: 3.1862, Train Acc: 0.3671, Eval Loss: 2.3000, Eval Acc: 0.4593
# [Transformer] Epoch 4/100, Train Loss: 2.5538, Train Acc: 0.4332, Eval Loss: 1.7188, Eval Acc: 0.6237
# [Transformer] Epoch 5/100, Train Loss: 2.0337, Train Acc: 0.5207, Eval Loss: 1.1549, Eval Acc: 0.7419
# [Transformer] Epoch 6/100, Train Loss: 1.5004, Train Acc: 0.6559, Eval Loss: 0.7857, Eval Acc: 0.8479
# [Transformer] Epoch 7/100, Train Loss: 1.1021, Train Acc: 0.7481, Eval Loss: 0.5392, Eval Acc: 0.9171
# [Transformer] Epoch 8/100, Train Loss: 0.7568, Train Acc: 0.8479, Eval Loss: 0.3376, Eval Acc: 0.9555
# [Transformer] Epoch 9/100, Train Loss: 0.6291, Train Acc: 0.8771, Eval Loss: 0.2300, Eval Acc: 0.9616
# [Transformer] Epoch 10/100, Train Loss: 0.4570, Train Acc: 0.9048, Eval Loss: 0.1610, Eval Acc: 0.9739
# [Transformer] Epoch 11/100, Train Loss: 0.3219, Train Acc: 0.9447, Eval Loss: 0.0731, Eval Acc: 0.9954
# [Transformer] Epoch 12/100, Train Loss: 0.2434, Train Acc: 0.9432, Eval Loss: 0.0687, Eval Acc: 0.9923
# [Transformer] Epoch 13/100, Train Loss: 0.2316, Train Acc: 0.9539, Eval Loss: 0.1376, Eval Acc: 0.9570
# [Transformer] Epoch 14/100, Train Loss: 0.2719, Train Acc: 0.9462, Eval Loss: 0.1150, Eval Acc: 0.9785
# [Transformer] Epoch 15/100, Train Loss: 0.2626, Train Acc: 0.9478, Eval Loss: 0.0861, Eval Acc: 0.9923
# [Transformer] Epoch 16/100, Train Loss: 0.2157, Train Acc: 0.9539, Eval Loss: 0.0862, Eval Acc: 0.9816
# [Transformer] Epoch 17/100, Train Loss: 0.2035, Train Acc: 0.9524, Eval Loss: 0.1009, Eval Acc: 0.9800
# [Transformer] Epoch 18/100, Train Loss: 0.1927, Train Acc: 0.9647, Eval Loss: 0.0505, Eval Acc: 0.9908
# [Transformer] Epoch 19/100, Train Loss: 0.1446, Train Acc: 0.9693, Eval Loss: 0.0484, Eval Acc: 0.9862
# [Transformer] Epoch 20/100, Train Loss: 0.1700, Train Acc: 0.9585, Eval Loss: 0.0989, Eval Acc: 0.9816
# [Transformer] Epoch 21/100, Train Loss: 0.2688, Train Acc: 0.9293, Eval Loss: 0.1122, Eval Acc: 0.9677
# [Transformer] Epoch 22/100, Train Loss: 0.4151, Train Acc: 0.8833, Eval Loss: 0.1218, Eval Acc: 0.9708
# [Transformer] Epoch 23/100, Train Loss: 0.2503, Train Acc: 0.9355, Eval Loss: 0.1192, Eval Acc: 0.9677
# [Transformer] Epoch 24/100, Train Loss: 0.2256, Train Acc: 0.9447, Eval Loss: 0.0634, Eval Acc: 0.9846
# [Transformer] Epoch 25/100, Train Loss: 0.1609, Train Acc: 0.9631, Eval Loss: 0.0484, Eval Acc: 0.9892
# [Transformer] Epoch 26/100, Train Loss: 0.0964, Train Acc: 0.9785, Eval Loss: 0.0379, Eval Acc: 0.9939
# [Transformer] Epoch 27/100, Train Loss: 0.0897, Train Acc: 0.9785, Eval Loss: 0.0208, Eval Acc: 0.9954
# [Transformer] Epoch 28/100, Train Loss: 0.1140, Train Acc: 0.9662, Eval Loss: 0.1006, Eval Acc: 0.9677
# [Transformer] Epoch 29/100, Train Loss: 0.2645, Train Acc: 0.9078, Eval Loss: 0.1126, Eval Acc: 0.9677
# [Transformer] Epoch 30/100, Train Loss: 0.2706, Train Acc: 0.9324, Eval Loss: 0.1406, Eval Acc: 0.9585
# [Transformer] Epoch 31/100, Train Loss: 0.2852, Train Acc: 0.9171, Eval Loss: 0.0701, Eval Acc: 0.9831
# [Transformer] Epoch 32/100, Train Loss: 0.3079, Train Acc: 0.9124, Eval Loss: 0.0952, Eval Acc: 0.9708
# [Transformer] Epoch 33/100, Train Loss: 0.3522, Train Acc: 0.8955, Eval Loss: 0.1342, Eval Acc: 0.9647
# [Transformer] Epoch 34/100, Train Loss: 0.3461, Train Acc: 0.9032, Eval Loss: 0.0704, Eval Acc: 0.9800
# [Transformer] Epoch 35/100, Train Loss: 0.2091, Train Acc: 0.9324, Eval Loss: 0.0608, Eval Acc: 0.9846
# [Transformer] Epoch 36/100, Train Loss: 0.1249, Train Acc: 0.9677, Eval Loss: 0.0347, Eval Acc: 0.9923
# [Transformer] Epoch 37/100, Train Loss: 0.1021, Train Acc: 0.9708, Eval Loss: 0.0197, Eval Acc: 0.9923
# [Transformer] Epoch 38/100, Train Loss: 0.1150, Train Acc: 0.9570, Eval Loss: 0.0565, Eval Acc: 0.9892
# [Transformer] Epoch 39/100, Train Loss: 0.1036, Train Acc: 0.9662, Eval Loss: 0.0315, Eval Acc: 0.9923
# [Transformer] Epoch 40/100, Train Loss: 0.0887, Train Acc: 0.9816, Eval Loss: 0.0194, Eval Acc: 0.9954
# [Transformer] Epoch 41/100, Train Loss: 0.0653, Train Acc: 0.9816, Eval Loss: 0.0136, Eval Acc: 0.9985
# [Transformer] Epoch 42/100, Train Loss: 0.0486, Train Acc: 0.9923, Eval Loss: 0.0229, Eval Acc: 0.9908
# [Transformer] Epoch 43/100, Train Loss: 0.0560, Train Acc: 0.9831, Eval Loss: 0.0074, Eval Acc: 0.9985
# [Transformer] Epoch 44/100, Train Loss: 0.0351, Train Acc: 0.9923, Eval Loss: 0.0039, Eval Acc: 0.9985
# [Transformer] Epoch 45/100, Train Loss: 0.0622, Train Acc: 0.9800, Eval Loss: 0.0167, Eval Acc: 0.9939
# [Transformer] Epoch 46/100, Train Loss: 0.1458, Train Acc: 0.9524, Eval Loss: 0.1060, Eval Acc: 0.9724
# [Transformer] Epoch 47/100, Train Loss: 0.4090, Train Acc: 0.8879, Eval Loss: 0.2699, Eval Acc: 0.9293
# [Transformer] Epoch 48/100, Train Loss: 0.5284, Train Acc: 0.8602, Eval Loss: 0.1755, Eval Acc: 0.9478
# [Transformer] Epoch 49/100, Train Loss: 0.4478, Train Acc: 0.8802, Eval Loss: 0.1870, Eval Acc: 0.9539
# [Transformer] Epoch 50/100, Train Loss: 0.3124, Train Acc: 0.9048, Eval Loss: 0.0904, Eval Acc: 0.9754
# [Transformer] Epoch 51/100, Train Loss: 0.1772, Train Acc: 0.9616, Eval Loss: 0.0457, Eval Acc: 0.9831
# [Transformer] Epoch 52/100, Train Loss: 0.1385, Train Acc: 0.9616, Eval Loss: 0.0313, Eval Acc: 0.9939
# [Transformer] Epoch 53/100, Train Loss: 0.0908, Train Acc: 0.9724, Eval Loss: 0.0320, Eval Acc: 0.9923
# [Transformer] Epoch 54/100, Train Loss: 0.1332, Train Acc: 0.9631, Eval Loss: 0.0393, Eval Acc: 0.9877
# [Transformer] Epoch 55/100, Train Loss: 0.1108, Train Acc: 0.9631, Eval Loss: 0.0243, Eval Acc: 0.9923
# [Transformer] Epoch 56/100, Train Loss: 0.0482, Train Acc: 0.9831, Eval Loss: 0.0072, Eval Acc: 0.9969
# [Transformer] Epoch 57/100, Train Loss: 0.0529, Train Acc: 0.9816, Eval Loss: 0.0105, Eval Acc: 0.9969
# [Transformer] Epoch 58/100, Train Loss: 0.0581, Train Acc: 0.9831, Eval Loss: 0.0288, Eval Acc: 0.9939
# [Transformer] Epoch 59/100, Train Loss: 0.0930, Train Acc: 0.9831, Eval Loss: 0.0254, Eval Acc: 0.9908
# [Transformer] Epoch 60/100, Train Loss: 0.0967, Train Acc: 0.9708, Eval Loss: 0.0574, Eval Acc: 0.9877
# [Transformer] Epoch 61/100, Train Loss: 0.1815, Train Acc: 0.9539, Eval Loss: 0.0727, Eval Acc: 0.9831
# [Transformer] Epoch 62/100, Train Loss: 0.1422, Train Acc: 0.9616, Eval Loss: 0.0661, Eval Acc: 0.9862
# [Transformer] Epoch 63/100, Train Loss: 0.1766, Train Acc: 0.9416, Eval Loss: 0.1026, Eval Acc: 0.9754
# [Transformer] Epoch 64/100, Train Loss: 0.2258, Train Acc: 0.9416, Eval Loss: 0.0321, Eval Acc: 0.9877
# [Transformer] Epoch 65/100, Train Loss: 0.2494, Train Acc: 0.9217, Eval Loss: 0.0915, Eval Acc: 0.9708
# [Transformer] Epoch 66/100, Train Loss: 0.3275, Train Acc: 0.8971, Eval Loss: 0.1069, Eval Acc: 0.9693
# [Transformer] Epoch 67/100, Train Loss: 0.3162, Train Acc: 0.9002, Eval Loss: 0.0771, Eval Acc: 0.9708
# [Transformer] Epoch 68/100, Train Loss: 0.2683, Train Acc: 0.9232, Eval Loss: 0.0402, Eval Acc: 0.9846
# [Transformer] Epoch 69/100, Train Loss: 0.1602, Train Acc: 0.9616, Eval Loss: 0.0128, Eval Acc: 0.9969
# [Transformer] Epoch 70/100, Train Loss: 0.1448, Train Acc: 0.9447, Eval Loss: 0.0320, Eval Acc: 0.9923
# [Transformer] Epoch 71/100, Train Loss: 0.1110, Train Acc: 0.9647, Eval Loss: 0.0219, Eval Acc: 0.9923
# [Transformer] Epoch 72/100, Train Loss: 0.0970, Train Acc: 0.9647, Eval Loss: 0.0052, Eval Acc: 1.0000
# [Transformer] Epoch 73/100, Train Loss: 0.0502, Train Acc: 0.9877, Eval Loss: 0.0039, Eval Acc: 1.0000
# [Transformer] Epoch 74/100, Train Loss: 0.0604, Train Acc: 0.9846, Eval Loss: 0.0261, Eval Acc: 0.9877
# [Transformer] Epoch 75/100, Train Loss: 0.0989, Train Acc: 0.9739, Eval Loss: 0.0242, Eval Acc: 0.9923
# [Transformer] Epoch 76/100, Train Loss: 0.1243, Train Acc: 0.9677, Eval Loss: 0.0614, Eval Acc: 0.9862
# [Transformer] Epoch 77/100, Train Loss: 0.1504, Train Acc: 0.9508, Eval Loss: 0.0381, Eval Acc: 0.9862
# [Transformer] Epoch 78/100, Train Loss: 0.1613, Train Acc: 0.9524, Eval Loss: 0.0340, Eval Acc: 0.9908
# [Transformer] Epoch 79/100, Train Loss: 0.1883, Train Acc: 0.9416, Eval Loss: 0.0989, Eval Acc: 0.9708
# [Transformer] Epoch 80/100, Train Loss: 0.3030, Train Acc: 0.9124, Eval Loss: 0.0608, Eval Acc: 0.9770
# [Transformer] Epoch 81/100, Train Loss: 0.3176, Train Acc: 0.9032, Eval Loss: 0.0605, Eval Acc: 0.9816
# [Transformer] Epoch 82/100, Train Loss: 0.2247, Train Acc: 0.9339, Eval Loss: 0.0582, Eval Acc: 0.9800
# [Transformer] Epoch 83/100, Train Loss: 0.1740, Train Acc: 0.9493, Eval Loss: 0.0308, Eval Acc: 0.9923
# [Transformer] Epoch 84/100, Train Loss: 0.2269, Train Acc: 0.9247, Eval Loss: 0.0671, Eval Acc: 0.9831
# [Transformer] Epoch 85/100, Train Loss: 0.1949, Train Acc: 0.9462, Eval Loss: 0.0444, Eval Acc: 0.9892
# [Transformer] Epoch 86/100, Train Loss: 0.1122, Train Acc: 0.9662, Eval Loss: 0.0166, Eval Acc: 0.9954
# [Transformer] Epoch 87/100, Train Loss: 0.1384, Train Acc: 0.9585, Eval Loss: 0.0561, Eval Acc: 0.9877
# [Transformer] Epoch 88/100, Train Loss: 0.0929, Train Acc: 0.9708, Eval Loss: 0.0150, Eval Acc: 0.9923
# [Transformer] Epoch 89/100, Train Loss: 0.0690, Train Acc: 0.9770, Eval Loss: 0.0140, Eval Acc: 0.9954
# [Transformer] Epoch 90/100, Train Loss: 0.0932, Train Acc: 0.9708, Eval Loss: 0.0247, Eval Acc: 0.9923
# [Transformer] Epoch 91/100, Train Loss: 0.0989, Train Acc: 0.9662, Eval Loss: 0.0426, Eval Acc: 0.9908
# [Transformer] Epoch 92/100, Train Loss: 0.2003, Train Acc: 0.9508, Eval Loss: 0.0579, Eval Acc: 0.9846
# [Transformer] Epoch 93/100, Train Loss: 0.1503, Train Acc: 0.9570, Eval Loss: 0.0655, Eval Acc: 0.9846
# [Transformer] Epoch 94/100, Train Loss: 0.1545, Train Acc: 0.9585, Eval Loss: 0.0594, Eval Acc: 0.9816
# [Transformer] Epoch 95/100, Train Loss: 0.1795, Train Acc: 0.9585, Eval Loss: 0.0378, Eval Acc: 0.9923
# [Transformer] Epoch 96/100, Train Loss: 0.1263, Train Acc: 0.9601, Eval Loss: 0.0256, Eval Acc: 0.9954
# [Transformer] Epoch 97/100, Train Loss: 0.1515, Train Acc: 0.9539, Eval Loss: 0.0550, Eval Acc: 0.9877
# [Transformer] Epoch 98/100, Train Loss: 0.1014, Train Acc: 0.9708, Eval Loss: 0.0409, Eval Acc: 0.9877
# [Transformer] Epoch 99/100, Train Loss: 0.1016, Train Acc: 0.9770, Eval Loss: 0.0208, Eval Acc: 0.9908
# [Transformer] Epoch 100/100, Train Loss: 0.0958, Train Acc: 0.9693, Eval Loss: 0.0086, Eval Acc: 1.0000
# Transformer training time: 64.47 seconds
# Config (2 layers, 4 heads): Final Eval Loss: 0.0086, Final Eval Acc: 1.0000
#
# Training Transformer with 4 layers and 2 heads
# [Transformer] Epoch 1/100, Train Loss: 5.3537, Train Acc: 0.1705, Eval Loss: 4.8317, Eval Acc: 0.1736
# [Transformer] Epoch 2/100, Train Loss: 4.8952, Train Acc: 0.1720, Eval Loss: 4.5300, Eval Acc: 0.1736
# [Transformer] Epoch 3/100, Train Loss: 4.7371, Train Acc: 0.1736, Eval Loss: 4.4839, Eval Acc: 0.1736
# [Transformer] Epoch 4/100, Train Loss: 4.6213, Train Acc: 0.1920, Eval Loss: 4.3393, Eval Acc: 0.1951
# [Transformer] Epoch 5/100, Train Loss: 4.5273, Train Acc: 0.1982, Eval Loss: 4.2933, Eval Acc: 0.1982
# [Transformer] Epoch 6/100, Train Loss: 4.7279, Train Acc: 0.1767, Eval Loss: 4.6042, Eval Acc: 0.1736
# [Transformer] Epoch 7/100, Train Loss: 4.7359, Train Acc: 0.1736, Eval Loss: 4.6010, Eval Acc: 0.1736
# [Transformer] Epoch 8/100, Train Loss: 4.7142, Train Acc: 0.1736, Eval Loss: 4.6213, Eval Acc: 0.1736
# [Transformer] Epoch 9/100, Train Loss: 4.6845, Train Acc: 0.1720, Eval Loss: 4.6211, Eval Acc: 0.1736
# [Transformer] Epoch 10/100, Train Loss: 4.6721, Train Acc: 0.1736, Eval Loss: 4.5864, Eval Acc: 0.1736
# [Transformer] Epoch 11/100, Train Loss: 4.6431, Train Acc: 0.1690, Eval Loss: 4.6036, Eval Acc: 0.1736
# [Transformer] Epoch 12/100, Train Loss: 4.6598, Train Acc: 0.1690, Eval Loss: 4.5977, Eval Acc: 0.1736
# [Transformer] Epoch 13/100, Train Loss: 4.6291, Train Acc: 0.1736, Eval Loss: 4.6528, Eval Acc: 0.1736
# [Transformer] Epoch 14/100, Train Loss: 4.6193, Train Acc: 0.1767, Eval Loss: 4.7119, Eval Acc: 0.0338
# [Transformer] Epoch 15/100, Train Loss: 4.6191, Train Acc: 0.1705, Eval Loss: 4.6229, Eval Acc: 0.1736
# [Transformer] Epoch 16/100, Train Loss: 4.5998, Train Acc: 0.1767, Eval Loss: 4.5992, Eval Acc: 0.1736
# [Transformer] Epoch 17/100, Train Loss: 4.5922, Train Acc: 0.1751, Eval Loss: 4.7011, Eval Acc: 0.0338
# [Transformer] Epoch 18/100, Train Loss: 4.5956, Train Acc: 0.1782, Eval Loss: 4.7017, Eval Acc: 0.1736
# [Transformer] Epoch 19/100, Train Loss: 4.5842, Train Acc: 0.1690, Eval Loss: 4.7574, Eval Acc: 0.0338
# [Transformer] Epoch 20/100, Train Loss: 4.5873, Train Acc: 0.1720, Eval Loss: 4.7291, Eval Acc: 0.0338
# [Transformer] Epoch 21/100, Train Loss: 4.6357, Train Acc: 0.1705, Eval Loss: 4.5904, Eval Acc: 0.1736
# [Transformer] Epoch 22/100, Train Loss: 4.5955, Train Acc: 0.1690, Eval Loss: 4.6232, Eval Acc: 0.1736
# [Transformer] Epoch 23/100, Train Loss: 4.5899, Train Acc: 0.1659, Eval Loss: 4.6318, Eval Acc: 0.1736
# [Transformer] Epoch 24/100, Train Loss: 4.5708, Train Acc: 0.1659, Eval Loss: 4.6796, Eval Acc: 0.1736
# [Transformer] Epoch 25/100, Train Loss: 4.5723, Train Acc: 0.1674, Eval Loss: 4.6647, Eval Acc: 0.1736
# [Transformer] Epoch 26/100, Train Loss: 4.5838, Train Acc: 0.1690, Eval Loss: 4.7492, Eval Acc: 0.0338
# [Transformer] Epoch 27/100, Train Loss: 4.5460, Train Acc: 0.1782, Eval Loss: 4.7613, Eval Acc: 0.0338
# [Transformer] Epoch 28/100, Train Loss: 4.5577, Train Acc: 0.1767, Eval Loss: 4.8766, Eval Acc: 0.0338
# [Transformer] Epoch 29/100, Train Loss: 4.5656, Train Acc: 0.1720, Eval Loss: 4.6596, Eval Acc: 0.1736
# [Transformer] Epoch 30/100, Train Loss: 4.5658, Train Acc: 0.1720, Eval Loss: 4.8433, Eval Acc: 0.0338
# [Transformer] Epoch 31/100, Train Loss: 4.5599, Train Acc: 0.1705, Eval Loss: 4.9100, Eval Acc: 0.0338
# [Transformer] Epoch 32/100, Train Loss: 4.5309, Train Acc: 0.1690, Eval Loss: 4.6951, Eval Acc: 0.1736
# [Transformer] Epoch 33/100, Train Loss: 4.5565, Train Acc: 0.1736, Eval Loss: 4.5802, Eval Acc: 0.1736
# [Transformer] Epoch 34/100, Train Loss: 4.5108, Train Acc: 0.1782, Eval Loss: 4.7573, Eval Acc: 0.0338
# [Transformer] Epoch 35/100, Train Loss: 4.5326, Train Acc: 0.1751, Eval Loss: 4.7566, Eval Acc: 0.0338
# [Transformer] Epoch 36/100, Train Loss: 4.5235, Train Acc: 0.1720, Eval Loss: 4.6641, Eval Acc: 0.1736
# [Transformer] Epoch 37/100, Train Loss: 4.5242, Train Acc: 0.1751, Eval Loss: 4.6861, Eval Acc: 0.1736
# [Transformer] Epoch 38/100, Train Loss: 4.5346, Train Acc: 0.1720, Eval Loss: 4.6826, Eval Acc: 0.1736
# [Transformer] Epoch 39/100, Train Loss: 4.5244, Train Acc: 0.1797, Eval Loss: 4.7737, Eval Acc: 0.0338
# [Transformer] Epoch 40/100, Train Loss: 4.5229, Train Acc: 0.1674, Eval Loss: 4.7089, Eval Acc: 0.1736
# [Transformer] Epoch 41/100, Train Loss: 4.5499, Train Acc: 0.1797, Eval Loss: 4.6590, Eval Acc: 0.1736
# [Transformer] Epoch 42/100, Train Loss: 4.5379, Train Acc: 0.1751, Eval Loss: 4.8588, Eval Acc: 0.0338
# [Transformer] Epoch 43/100, Train Loss: 4.5168, Train Acc: 0.1874, Eval Loss: 4.9234, Eval Acc: 0.0338
# [Transformer] Epoch 44/100, Train Loss: 4.4780, Train Acc: 0.1843, Eval Loss: 4.7344, Eval Acc: 0.0338
# [Transformer] Epoch 45/100, Train Loss: 4.4892, Train Acc: 0.1905, Eval Loss: 5.0305, Eval Acc: 0.0338
# [Transformer] Epoch 46/100, Train Loss: 4.4132, Train Acc: 0.1874, Eval Loss: 5.1365, Eval Acc: 0.0338
# [Transformer] Epoch 47/100, Train Loss: 4.4493, Train Acc: 0.1813, Eval Loss: 5.0255, Eval Acc: 0.0338
# [Transformer] Epoch 48/100, Train Loss: 4.3740, Train Acc: 0.1889, Eval Loss: 5.1480, Eval Acc: 0.0338
# [Transformer] Epoch 49/100, Train Loss: 4.3880, Train Acc: 0.1889, Eval Loss: 4.9749, Eval Acc: 0.0338
# [Transformer] Epoch 50/100, Train Loss: 4.3504, Train Acc: 0.2043, Eval Loss: 5.3887, Eval Acc: 0.0338
# [Transformer] Epoch 51/100, Train Loss: 4.3978, Train Acc: 0.1966, Eval Loss: 5.2728, Eval Acc: 0.0338
# [Transformer] Epoch 52/100, Train Loss: 4.3930, Train Acc: 0.1889, Eval Loss: 5.1796, Eval Acc: 0.0338
# [Transformer] Epoch 53/100, Train Loss: 4.3536, Train Acc: 0.1951, Eval Loss: 5.3522, Eval Acc: 0.0338
# [Transformer] Epoch 54/100, Train Loss: 4.3326, Train Acc: 0.1935, Eval Loss: 5.8199, Eval Acc: 0.0338
# [Transformer] Epoch 55/100, Train Loss: 4.3200, Train Acc: 0.2058, Eval Loss: 4.7277, Eval Acc: 0.0338
# [Transformer] Epoch 56/100, Train Loss: 4.3494, Train Acc: 0.1966, Eval Loss: 4.9755, Eval Acc: 0.0338
# [Transformer] Epoch 57/100, Train Loss: 4.3510, Train Acc: 0.1982, Eval Loss: 5.0691, Eval Acc: 0.0338
# [Transformer] Epoch 58/100, Train Loss: 4.3891, Train Acc: 0.1889, Eval Loss: 5.2315, Eval Acc: 0.0338
# [Transformer] Epoch 59/100, Train Loss: 4.3241, Train Acc: 0.1966, Eval Loss: 4.6808, Eval Acc: 0.1736
# [Transformer] Epoch 60/100, Train Loss: 4.2932, Train Acc: 0.2012, Eval Loss: 5.4956, Eval Acc: 0.0338
# [Transformer] Epoch 61/100, Train Loss: 4.2606, Train Acc: 0.1905, Eval Loss: 6.6795, Eval Acc: 0.0338
# [Transformer] Epoch 62/100, Train Loss: 4.3190, Train Acc: 0.1982, Eval Loss: 5.8419, Eval Acc: 0.0338
# [Transformer] Epoch 63/100, Train Loss: 4.3619, Train Acc: 0.1935, Eval Loss: 4.8693, Eval Acc: 0.0338
# [Transformer] Epoch 64/100, Train Loss: 4.3369, Train Acc: 0.1889, Eval Loss: 6.2673, Eval Acc: 0.0338
# [Transformer] Epoch 65/100, Train Loss: 4.3069, Train Acc: 0.1966, Eval Loss: 5.3932, Eval Acc: 0.0338
# [Transformer] Epoch 66/100, Train Loss: 4.2812, Train Acc: 0.1951, Eval Loss: 4.8884, Eval Acc: 0.0338
# [Transformer] Epoch 67/100, Train Loss: 4.3056, Train Acc: 0.1905, Eval Loss: 5.7897, Eval Acc: 0.0338
# [Transformer] Epoch 68/100, Train Loss: 4.3247, Train Acc: 0.1951, Eval Loss: 5.4146, Eval Acc: 0.0338
# [Transformer] Epoch 69/100, Train Loss: 4.3366, Train Acc: 0.1920, Eval Loss: 5.7960, Eval Acc: 0.0338
# [Transformer] Epoch 70/100, Train Loss: 4.3218, Train Acc: 0.1997, Eval Loss: 5.4822, Eval Acc: 0.0338
# [Transformer] Epoch 71/100, Train Loss: 4.2843, Train Acc: 0.1859, Eval Loss: 6.5728, Eval Acc: 0.0338
# [Transformer] Epoch 72/100, Train Loss: 4.3063, Train Acc: 0.1920, Eval Loss: 5.2816, Eval Acc: 0.0338
# [Transformer] Epoch 73/100, Train Loss: 4.2664, Train Acc: 0.1982, Eval Loss: 5.4516, Eval Acc: 0.0338
# [Transformer] Epoch 74/100, Train Loss: 4.2883, Train Acc: 0.2058, Eval Loss: 5.7038, Eval Acc: 0.0338
# [Transformer] Epoch 75/100, Train Loss: 4.2589, Train Acc: 0.1997, Eval Loss: 5.8108, Eval Acc: 0.0338
# [Transformer] Epoch 76/100, Train Loss: 4.2800, Train Acc: 0.2089, Eval Loss: 6.9271, Eval Acc: 0.0338
# [Transformer] Epoch 77/100, Train Loss: 4.2866, Train Acc: 0.1951, Eval Loss: 6.2517, Eval Acc: 0.0338
# [Transformer] Epoch 78/100, Train Loss: 4.3001, Train Acc: 0.1889, Eval Loss: 6.9970, Eval Acc: 0.0338
# [Transformer] Epoch 79/100, Train Loss: 4.2594, Train Acc: 0.1951, Eval Loss: 5.8570, Eval Acc: 0.0338
# [Transformer] Epoch 80/100, Train Loss: 4.2551, Train Acc: 0.1859, Eval Loss: 6.8743, Eval Acc: 0.0338
# [Transformer] Epoch 81/100, Train Loss: 4.2631, Train Acc: 0.1951, Eval Loss: 6.3244, Eval Acc: 0.0338
# [Transformer] Epoch 82/100, Train Loss: 4.2715, Train Acc: 0.1905, Eval Loss: 6.5312, Eval Acc: 0.0338
# [Transformer] Epoch 83/100, Train Loss: 4.3275, Train Acc: 0.1920, Eval Loss: 5.9039, Eval Acc: 0.0338
# [Transformer] Epoch 84/100, Train Loss: 4.2979, Train Acc: 0.1982, Eval Loss: 6.4691, Eval Acc: 0.0338
# [Transformer] Epoch 85/100, Train Loss: 4.2522, Train Acc: 0.1951, Eval Loss: 5.9270, Eval Acc: 0.0338
# [Transformer] Epoch 86/100, Train Loss: 4.2496, Train Acc: 0.1920, Eval Loss: 5.7537, Eval Acc: 0.0338
# [Transformer] Epoch 87/100, Train Loss: 4.2562, Train Acc: 0.1905, Eval Loss: 5.6665, Eval Acc: 0.0338
# [Transformer] Epoch 88/100, Train Loss: 4.2315, Train Acc: 0.1951, Eval Loss: 6.6501, Eval Acc: 0.0338
# [Transformer] Epoch 89/100, Train Loss: 4.2994, Train Acc: 0.1905, Eval Loss: 6.0742, Eval Acc: 0.0338
# [Transformer] Epoch 90/100, Train Loss: 4.2915, Train Acc: 0.1951, Eval Loss: 6.5843, Eval Acc: 0.0338
# [Transformer] Epoch 91/100, Train Loss: 4.2756, Train Acc: 0.2058, Eval Loss: 5.9824, Eval Acc: 0.0338
# [Transformer] Epoch 92/100, Train Loss: 4.2660, Train Acc: 0.1905, Eval Loss: 7.1541, Eval Acc: 0.0338
# [Transformer] Epoch 93/100, Train Loss: 4.2987, Train Acc: 0.1951, Eval Loss: 6.5044, Eval Acc: 0.0338
# [Transformer] Epoch 94/100, Train Loss: 4.2507, Train Acc: 0.1982, Eval Loss: 6.5768, Eval Acc: 0.0338
# [Transformer] Epoch 95/100, Train Loss: 4.2783, Train Acc: 0.1935, Eval Loss: 5.2656, Eval Acc: 0.0338
# [Transformer] Epoch 96/100, Train Loss: 4.2452, Train Acc: 0.2074, Eval Loss: 5.7241, Eval Acc: 0.0338
# [Transformer] Epoch 97/100, Train Loss: 4.2413, Train Acc: 0.2028, Eval Loss: 6.4296, Eval Acc: 0.0338
# [Transformer] Epoch 98/100, Train Loss: 4.2438, Train Acc: 0.1982, Eval Loss: 6.6563, Eval Acc: 0.0338
# [Transformer] Epoch 99/100, Train Loss: 4.2278, Train Acc: 0.2028, Eval Loss: 7.4649, Eval Acc: 0.0338
# [Transformer] Epoch 100/100, Train Loss: 4.2586, Train Acc: 0.1997, Eval Loss: 6.3884, Eval Acc: 0.0338
# Transformer training time: 126.92 seconds
# Config (4 layers, 2 heads): Final Eval Loss: 6.3884, Final Eval Acc: 0.0338
#
# Training Transformer with 4 layers and 4 heads
# [Transformer] Epoch 1/100, Train Loss: 5.3794, Train Acc: 0.1659, Eval Loss: 4.8299, Eval Acc: 0.1736
# [Transformer] Epoch 2/100, Train Loss: 4.7857, Train Acc: 0.1920, Eval Loss: 4.4790, Eval Acc: 0.2074
# [Transformer] Epoch 3/100, Train Loss: 4.5009, Train Acc: 0.2089, Eval Loss: 4.1772, Eval Acc: 0.2243
# [Transformer] Epoch 4/100, Train Loss: 4.3791, Train Acc: 0.2120, Eval Loss: 4.1782, Eval Acc: 0.2074
# [Transformer] Epoch 5/100, Train Loss: 4.3312, Train Acc: 0.2074, Eval Loss: 4.1541, Eval Acc: 0.2074
# [Transformer] Epoch 6/100, Train Loss: 4.3137, Train Acc: 0.2012, Eval Loss: 4.1409, Eval Acc: 0.2074
# [Transformer] Epoch 7/100, Train Loss: 4.2974, Train Acc: 0.1982, Eval Loss: 4.1439, Eval Acc: 0.2074
# [Transformer] Epoch 8/100, Train Loss: 4.2803, Train Acc: 0.2058, Eval Loss: 4.1632, Eval Acc: 0.2304
# [Transformer] Epoch 9/100, Train Loss: 4.2644, Train Acc: 0.1951, Eval Loss: 4.1458, Eval Acc: 0.2074
# [Transformer] Epoch 10/100, Train Loss: 4.2618, Train Acc: 0.2028, Eval Loss: 4.1282, Eval Acc: 0.2074
# [Transformer] Epoch 11/100, Train Loss: 4.2556, Train Acc: 0.2012, Eval Loss: 4.1303, Eval Acc: 0.2074
# [Transformer] Epoch 12/100, Train Loss: 4.2596, Train Acc: 0.1997, Eval Loss: 4.1409, Eval Acc: 0.2074
# [Transformer] Epoch 13/100, Train Loss: 4.2405, Train Acc: 0.2012, Eval Loss: 4.1228, Eval Acc: 0.2074
# [Transformer] Epoch 14/100, Train Loss: 4.2299, Train Acc: 0.2012, Eval Loss: 4.1254, Eval Acc: 0.2074
# [Transformer] Epoch 15/100, Train Loss: 4.2323, Train Acc: 0.2043, Eval Loss: 4.1151, Eval Acc: 0.2074
# [Transformer] Epoch 16/100, Train Loss: 4.2783, Train Acc: 0.2074, Eval Loss: 4.1589, Eval Acc: 0.2074
# [Transformer] Epoch 17/100, Train Loss: 4.2350, Train Acc: 0.1966, Eval Loss: 4.1222, Eval Acc: 0.2074
# [Transformer] Epoch 18/100, Train Loss: 4.2090, Train Acc: 0.2197, Eval Loss: 4.0961, Eval Acc: 0.2074
# [Transformer] Epoch 19/100, Train Loss: 4.1907, Train Acc: 0.1966, Eval Loss: 4.1145, Eval Acc: 0.2074
# [Transformer] Epoch 20/100, Train Loss: 4.2064, Train Acc: 0.2012, Eval Loss: 4.0879, Eval Acc: 0.2243
# [Transformer] Epoch 21/100, Train Loss: 4.2035, Train Acc: 0.2074, Eval Loss: 4.0985, Eval Acc: 0.2074
# [Transformer] Epoch 22/100, Train Loss: 4.7938, Train Acc: 0.1705, Eval Loss: 4.6056, Eval Acc: 0.1736
# [Transformer] Epoch 23/100, Train Loss: 4.7042, Train Acc: 0.1736, Eval Loss: 4.5991, Eval Acc: 0.1736
# [Transformer] Epoch 24/100, Train Loss: 4.6847, Train Acc: 0.1736, Eval Loss: 4.5852, Eval Acc: 0.1736
# [Transformer] Epoch 25/100, Train Loss: 4.6814, Train Acc: 0.1736, Eval Loss: 4.5850, Eval Acc: 0.1736
# [Transformer] Epoch 26/100, Train Loss: 4.6654, Train Acc: 0.1736, Eval Loss: 4.5824, Eval Acc: 0.1736
# [Transformer] Epoch 27/100, Train Loss: 4.6011, Train Acc: 0.1736, Eval Loss: 4.5888, Eval Acc: 0.1736
# [Transformer] Epoch 28/100, Train Loss: 4.5831, Train Acc: 0.1813, Eval Loss: 4.7520, Eval Acc: 0.0338
# [Transformer] Epoch 29/100, Train Loss: 4.4767, Train Acc: 0.1935, Eval Loss: 5.8838, Eval Acc: 0.0338
# [Transformer] Epoch 30/100, Train Loss: 4.3575, Train Acc: 0.1951, Eval Loss: 7.4923, Eval Acc: 0.0338
# [Transformer] Epoch 31/100, Train Loss: 4.3600, Train Acc: 0.1813, Eval Loss: 6.1947, Eval Acc: 0.0338
# [Transformer] Epoch 32/100, Train Loss: 4.3564, Train Acc: 0.2043, Eval Loss: 5.6760, Eval Acc: 0.0338
# [Transformer] Epoch 33/100, Train Loss: 4.3708, Train Acc: 0.1966, Eval Loss: 5.2008, Eval Acc: 0.0338
# [Transformer] Epoch 34/100, Train Loss: 4.3811, Train Acc: 0.1920, Eval Loss: 5.0757, Eval Acc: 0.0338
# [Transformer] Epoch 35/100, Train Loss: 4.3686, Train Acc: 0.2012, Eval Loss: 5.0467, Eval Acc: 0.0338
# [Transformer] Epoch 36/100, Train Loss: 4.3519, Train Acc: 0.1997, Eval Loss: 5.5913, Eval Acc: 0.0338
# [Transformer] Epoch 37/100, Train Loss: 4.3521, Train Acc: 0.1982, Eval Loss: 5.8777, Eval Acc: 0.0338
# [Transformer] Epoch 38/100, Train Loss: 4.3071, Train Acc: 0.1951, Eval Loss: 5.8966, Eval Acc: 0.0338
# [Transformer] Epoch 39/100, Train Loss: 4.3161, Train Acc: 0.1935, Eval Loss: 6.9501, Eval Acc: 0.0338
# [Transformer] Epoch 40/100, Train Loss: 4.3187, Train Acc: 0.2089, Eval Loss: 6.3934, Eval Acc: 0.0338
# [Transformer] Epoch 41/100, Train Loss: 4.2884, Train Acc: 0.1982, Eval Loss: 5.8833, Eval Acc: 0.0338
# [Transformer] Epoch 42/100, Train Loss: 4.2793, Train Acc: 0.1966, Eval Loss: 6.5582, Eval Acc: 0.0338
# [Transformer] Epoch 43/100, Train Loss: 4.2447, Train Acc: 0.1997, Eval Loss: 5.9767, Eval Acc: 0.0338
# [Transformer] Epoch 44/100, Train Loss: 4.2681, Train Acc: 0.1982, Eval Loss: 5.9726, Eval Acc: 0.0338
# [Transformer] Epoch 45/100, Train Loss: 4.2713, Train Acc: 0.2058, Eval Loss: 6.7732, Eval Acc: 0.0338
# [Transformer] Epoch 46/100, Train Loss: 4.2843, Train Acc: 0.1997, Eval Loss: 5.9545, Eval Acc: 0.0338
# [Transformer] Epoch 47/100, Train Loss: 4.2530, Train Acc: 0.2043, Eval Loss: 6.9681, Eval Acc: 0.0338
# [Transformer] Epoch 48/100, Train Loss: 4.2343, Train Acc: 0.1982, Eval Loss: 6.1084, Eval Acc: 0.0338
# [Transformer] Epoch 49/100, Train Loss: 4.2915, Train Acc: 0.1813, Eval Loss: 6.2122, Eval Acc: 0.0338
# [Transformer] Epoch 50/100, Train Loss: 4.2208, Train Acc: 0.1966, Eval Loss: 5.9099, Eval Acc: 0.0338
# [Transformer] Epoch 51/100, Train Loss: 4.2682, Train Acc: 0.1982, Eval Loss: 6.7616, Eval Acc: 0.0338
# [Transformer] Epoch 52/100, Train Loss: 4.2883, Train Acc: 0.1935, Eval Loss: 5.9834, Eval Acc: 0.0338
# [Transformer] Epoch 53/100, Train Loss: 4.2471, Train Acc: 0.1920, Eval Loss: 5.5397, Eval Acc: 0.0338
# [Transformer] Epoch 54/100, Train Loss: 4.2157, Train Acc: 0.2012, Eval Loss: 7.0338, Eval Acc: 0.0338
# [Transformer] Epoch 55/100, Train Loss: 4.2825, Train Acc: 0.1982, Eval Loss: 5.5378, Eval Acc: 0.0338
# [Transformer] Epoch 56/100, Train Loss: 4.2470, Train Acc: 0.1951, Eval Loss: 5.8707, Eval Acc: 0.0338
# [Transformer] Epoch 57/100, Train Loss: 4.2609, Train Acc: 0.1966, Eval Loss: 6.1137, Eval Acc: 0.0338
# [Transformer] Epoch 58/100, Train Loss: 4.2124, Train Acc: 0.1982, Eval Loss: 6.9177, Eval Acc: 0.0338
# [Transformer] Epoch 59/100, Train Loss: 4.2050, Train Acc: 0.1874, Eval Loss: 6.8598, Eval Acc: 0.0338
# [Transformer] Epoch 60/100, Train Loss: 4.2314, Train Acc: 0.2089, Eval Loss: 6.5818, Eval Acc: 0.0338
# [Transformer] Epoch 61/100, Train Loss: 4.2273, Train Acc: 0.2166, Eval Loss: 6.4433, Eval Acc: 0.0338
# [Transformer] Epoch 62/100, Train Loss: 4.2419, Train Acc: 0.1997, Eval Loss: 5.5994, Eval Acc: 0.0338
# [Transformer] Epoch 63/100, Train Loss: 4.2596, Train Acc: 0.1951, Eval Loss: 6.0477, Eval Acc: 0.0338
# [Transformer] Epoch 64/100, Train Loss: 4.2234, Train Acc: 0.1997, Eval Loss: 5.9021, Eval Acc: 0.0338
# [Transformer] Epoch 65/100, Train Loss: 4.1873, Train Acc: 0.1951, Eval Loss: 6.5087, Eval Acc: 0.0338
# [Transformer] Epoch 66/100, Train Loss: 4.2106, Train Acc: 0.1997, Eval Loss: 6.5108, Eval Acc: 0.0338
# [Transformer] Epoch 67/100, Train Loss: 4.1918, Train Acc: 0.1951, Eval Loss: 6.7399, Eval Acc: 0.0338
# [Transformer] Epoch 68/100, Train Loss: 4.1913, Train Acc: 0.2012, Eval Loss: 5.6234, Eval Acc: 0.0338
# [Transformer] Epoch 69/100, Train Loss: 4.2275, Train Acc: 0.1997, Eval Loss: 5.7415, Eval Acc: 0.0338
# [Transformer] Epoch 70/100, Train Loss: 4.2587, Train Acc: 0.1966, Eval Loss: 5.5961, Eval Acc: 0.0338
# [Transformer] Epoch 71/100, Train Loss: 4.1866, Train Acc: 0.1982, Eval Loss: 5.4929, Eval Acc: 0.0338
# [Transformer] Epoch 72/100, Train Loss: 4.2229, Train Acc: 0.1997, Eval Loss: 6.1176, Eval Acc: 0.0338
# [Transformer] Epoch 73/100, Train Loss: 4.2320, Train Acc: 0.1951, Eval Loss: 5.9215, Eval Acc: 0.0338
# [Transformer] Epoch 74/100, Train Loss: 4.2107, Train Acc: 0.1966, Eval Loss: 6.6151, Eval Acc: 0.0338
# [Transformer] Epoch 75/100, Train Loss: 4.2365, Train Acc: 0.1966, Eval Loss: 5.9941, Eval Acc: 0.0338
# [Transformer] Epoch 76/100, Train Loss: 4.2139, Train Acc: 0.1997, Eval Loss: 6.6190, Eval Acc: 0.0338
# [Transformer] Epoch 77/100, Train Loss: 4.1889, Train Acc: 0.2058, Eval Loss: 6.8777, Eval Acc: 0.0338
# [Transformer] Epoch 78/100, Train Loss: 4.2058, Train Acc: 0.2012, Eval Loss: 5.8464, Eval Acc: 0.0338
# [Transformer] Epoch 79/100, Train Loss: 4.2228, Train Acc: 0.1982, Eval Loss: 5.8392, Eval Acc: 0.0338
# [Transformer] Epoch 80/100, Train Loss: 4.1809, Train Acc: 0.1935, Eval Loss: 5.6671, Eval Acc: 0.0338
# [Transformer] Epoch 81/100, Train Loss: 4.1811, Train Acc: 0.1951, Eval Loss: 5.6684, Eval Acc: 0.0338
# [Transformer] Epoch 82/100, Train Loss: 4.1858, Train Acc: 0.1982, Eval Loss: 5.5201, Eval Acc: 0.0338
# [Transformer] Epoch 83/100, Train Loss: 4.2028, Train Acc: 0.1905, Eval Loss: 5.6969, Eval Acc: 0.0338
# [Transformer] Epoch 84/100, Train Loss: 4.1486, Train Acc: 0.2028, Eval Loss: 5.8565, Eval Acc: 0.0338
# [Transformer] Epoch 85/100, Train Loss: 4.2073, Train Acc: 0.2028, Eval Loss: 6.5420, Eval Acc: 0.0338
# [Transformer] Epoch 86/100, Train Loss: 4.2487, Train Acc: 0.1997, Eval Loss: 6.3802, Eval Acc: 0.0338
# [Transformer] Epoch 87/100, Train Loss: 4.1983, Train Acc: 0.1951, Eval Loss: 6.6563, Eval Acc: 0.0338
# [Transformer] Epoch 88/100, Train Loss: 4.1778, Train Acc: 0.2135, Eval Loss: 6.0909, Eval Acc: 0.0338
# [Transformer] Epoch 89/100, Train Loss: 4.1995, Train Acc: 0.2058, Eval Loss: 6.2843, Eval Acc: 0.0338
# [Transformer] Epoch 90/100, Train Loss: 4.1903, Train Acc: 0.2043, Eval Loss: 5.6043, Eval Acc: 0.0338
# [Transformer] Epoch 91/100, Train Loss: 4.2280, Train Acc: 0.1997, Eval Loss: 5.7471, Eval Acc: 0.0338
# [Transformer] Epoch 92/100, Train Loss: 4.1430, Train Acc: 0.2028, Eval Loss: 7.5861, Eval Acc: 0.0338
# [Transformer] Epoch 93/100, Train Loss: 4.2140, Train Acc: 0.2074, Eval Loss: 6.2391, Eval Acc: 0.0338
# [Transformer] Epoch 94/100, Train Loss: 4.1226, Train Acc: 0.2012, Eval Loss: 6.3618, Eval Acc: 0.0338
# [Transformer] Epoch 95/100, Train Loss: 4.2355, Train Acc: 0.2074, Eval Loss: 6.7756, Eval Acc: 0.0338
# [Transformer] Epoch 96/100, Train Loss: 4.1648, Train Acc: 0.2089, Eval Loss: 5.9606, Eval Acc: 0.0338
# [Transformer] Epoch 97/100, Train Loss: 4.2111, Train Acc: 0.2028, Eval Loss: 6.3866, Eval Acc: 0.0338
# [Transformer] Epoch 98/100, Train Loss: 4.1537, Train Acc: 0.1966, Eval Loss: 6.3626, Eval Acc: 0.0338
# [Transformer] Epoch 99/100, Train Loss: 4.1640, Train Acc: 0.2058, Eval Loss: 7.1863, Eval Acc: 0.0338
# [Transformer] Epoch 100/100, Train Loss: 4.1418, Train Acc: 0.1966, Eval Loss: 7.0416, Eval Acc: 0.0338
# Transformer training time: 127.82 seconds
# Config (4 layers, 4 heads): Final Eval Loss: 7.0416, Final Eval Acc: 0.0338

# %%
# Plot Transformer validation accuracy for all configurations
plt.figure(figsize=(12, 8))
for res in transformer_results:
    label = f"{res['n_layers']} layers, {res['n_heads']} heads"
    plt.plot(range(n_epochs_trans), res['val_accuracies'], label=label)
plt.xlabel('Epoch')
plt.ylabel('Validation Accuracy')
plt.title('Transformer Validation Accuracy for Different Configurations')
plt.legend()
plt.tight_layout()
plt.savefig("images/hw5_p3_transformer_configs_accuracy.png")
plt.show()

# Plot Transformer training loss for all configurations
plt.figure(figsize=(12, 8))
for res in transformer_results:
    label = f"{res['n_layers']} layers, {res['n_heads']} heads"
    plt.plot(range(n_epochs_trans), res['train_losses'], label=label)
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('Transformer Training Loss for Different Configurations')
plt.legend()
plt.tight_layout()
plt.savefig("images/hw5_p3_transformer_configs_loss.png")
plt.show()

# Now, for overall comparison, you may want to overlay the best (or average) Transformer curve 
# with the RNN-based models:
plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
plt.plot(range(n_epochs), rnn_train_losses, label='RNN Train Loss')
plt.plot(range(n_epochs), rnn_val_losses, label='RNN Val Loss')
plt.plot(range(n_epochs), attn_train_losses, label='Attn RNN Train Loss')
plt.plot(range(n_epochs), attn_val_losses, label='Attn RNN Val Loss')

selected_trans = None
for res in transformer_results:
    if res['n_layers'] == 2 and res['n_heads'] == 2:
        selected_trans = res
        break
if selected_trans is not None:
    plt.plot(range(n_epochs_trans), selected_trans['train_losses'], label='Transformer Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Comparison (RNN & Transformer)')
plt.legend()
plt.tight_layout()
plt.savefig("images/hw5_p3_loss_comparison.png")
plt.show()

plt.figure(figsize=(12, 5))
plt.plot(range(n_epochs), rnn_val_accuracies, label='RNN Val Acc')
plt.plot(range(n_epochs), attn_val_accuracies, label='Attn RNN Val Acc')
if selected_trans is not None:
    plt.plot(range(n_epochs_trans), selected_trans['val_accuracies'], label='Transformer Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Token Accuracy')
plt.title('Validation Accuracy Comparison (RNN & Transformer)')
plt.legend()
plt.tight_layout()
plt.savefig("images/hw5_p3_accuracy_comparison.png")
plt.show()

# %%
# Sample translations for each model
def translate_rnn(input_tensor, encoder, decoder):
    encoder_hidden = encoder.initHidden()
    input_length = input_tensor.size(0)
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei].unsqueeze(0), encoder_hidden)
    decoder_input = torch.tensor([SOS_token], device=device)
    decoder_hidden = encoder_hidden
    predicted_indices = []
    while True:
        decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
        topv, topi = decoder_output.topk(1)
        predicted_indices.append(topi.item())
        decoder_input = topi.squeeze().detach()
        if decoder_input.item() == EOS_token or len(predicted_indices) > 50:
            break
    return predicted_indices

def translate_attn(input_tensor, encoder, decoder, max_length=50):
    encoder_hidden = encoder.initHidden()
    input_length = input_tensor.size(0)
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei].unsqueeze(0), encoder_hidden)
        if ei < max_length:
            encoder_outputs[ei] = encoder_output[0, 0]
    decoder_input = torch.tensor([SOS_token], device=device)
    decoder_hidden = encoder_hidden
    predicted_indices = []
    while True:
        decoder_output, decoder_hidden, attn_weights = decoder(decoder_input, decoder_hidden, encoder_outputs)
        topv, topi = decoder_output.topk(1)
        predicted_indices.append(topi.item())
        decoder_input = topi.squeeze().detach()
        if decoder_input.item() == EOS_token or len(predicted_indices) > 50:
            break
    return predicted_indices

def translate_transformer(model, src_sentence, max_len=50):
    model.eval()
    with torch.no_grad():
        # src_sentence is a tensor from the source sequence (with EOS token)
        src = src_sentence.unsqueeze(0).to(device)  # (1, src_len)
        memory = model.encoder(src)
        # Start decoding with SOS token
        tgt_indices = [SOS_token]
        for i in range(max_len):
            tgt = torch.tensor(tgt_indices, dtype=torch.long).unsqueeze(0).to(device)
            tgt_mask = generate_square_subsequent_mask(tgt.size(1)).to(device)
            output = model.decoder(tgt, memory, tgt_mask=tgt_mask)
            next_token = output[0, -1].argmax().item()
            tgt_indices.append(next_token)
            if next_token == EOS_token:
                break
        return tgt_indices

# Display sample translations (show 3 examples)
print("\nSample Translations:")
num_examples = 3
sample_count = 0
for input_tensor, target_tensor in dataloader:
    input_tensor = input_tensor.squeeze(0).to(device)
    target_tensor = target_tensor.squeeze(0).to(device)
    
    # RNN (without attention)
    pred_rnn = translate_rnn(input_tensor, encoder_gru, decoder_gru)
    # RNN with attention
    pred_attn = translate_attn(input_tensor, encoder_attn, decoder_attn, max_length=50)
    # Transformer using the "base" model (if needed)
    pred_trans_base = translate_transformer(transformer_model, input_tensor, max_len=50)
    
    src_sentence = " ".join([index_to_word[idx.item()] for idx in input_tensor if idx.item() not in [SOS_token, EOS_token]])
    tgt_sentence = " ".join([index_to_word[idx.item()] for idx in target_tensor if idx.item() not in [SOS_token, EOS_token]])
    pred_sentence_rnn = " ".join([index_to_word[idx] for idx in pred_rnn if idx not in [SOS_token, EOS_token]])
    pred_sentence_attn = " ".join([index_to_word[idx] for idx in pred_attn if idx not in [SOS_token, EOS_token]])
    pred_sentence_trans_base = " ".join([index_to_word[idx] for idx in pred_trans_base if idx not in [SOS_token, EOS_token]])
    
    print("Source   :", src_sentence)
    print("Target   :", tgt_sentence)
    print("RNN Pred :", pred_sentence_rnn)
    print("Attn Pred:", pred_sentence_attn)
    print("Transformer (base) Pred:", pred_sentence_trans_base)
    
    # Now display predictions for each Transformer configuration
    for config in transformer_results:
        label = f"Transformer ({config['n_layers']} layers, {config['n_heads']} heads)"
        model_config = config['model']
        pred_trans = translate_transformer(model_config, input_tensor, max_len=50)
        pred_sentence_trans = " ".join([index_to_word[idx] for idx in pred_trans if idx not in [SOS_token, EOS_token]])
        print(label, "Pred:", pred_sentence_trans)
    
    print("-" * 50)
    sample_count += 1
    if sample_count >= num_examples:
        break
# Out:
# Sample Translations:
# Source   : They swim in the pool
# Target   : Ils nagent dans la piscine
# RNN Pred : Ils nagent dans la piscine
# Attn Pred: Ils nagent dans la piscine
# Transformer (base) Pred: au barks drives gazouillent libre 19 dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films dances jouons clock films
# Transformer (1 layers, 2 heads) Pred: Ils nagent dans la piscine
# Transformer (1 layers, 4 heads) Pred: Ils nagent dans la piscine
# Transformer (2 layers, 2 heads) Pred: Ils nagent dans la piscine
# Transformer (2 layers, 4 heads) Pred: Ils nagent dans la piscine
# Transformer (4 layers, 2 heads) Pred: Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous
# Transformer (4 layers, 4 heads) Pred: Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il
# --------------------------------------------------
# Source   : They go shopping
# Target   : Ils font du shopping
# RNN Pred : Ils font du shopping
# Attn Pred: Ils font du shopping
# Transformer (base) Pred: English doucement parc bon du vendredi teaches are travel brightly un river runs lettre court Il are on bloom montagne are on bloom montagne are on bloom teaches regardons breakfast décolle are on bloom montagne are on bloom teaches chien study are on something déjeuner souvent visite Paris ride video
# Transformer (1 layers, 2 heads) Pred: Ils font du shopping
# Transformer (1 layers, 4 heads) Pred: Ils font du shopping
# Transformer (2 layers, 2 heads) Pred: Ils font du vélo
# Transformer (2 layers, 4 heads) Pred: Ils font du shopping
# Transformer (4 layers, 2 heads) Pred: Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous
# Transformer (4 layers, 4 heads) Pred: Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il
# --------------------------------------------------
# Source   : They listen to the radio
# Target   : Ils écoutent la radio
# RNN Pred : Ils écoutent la radio
# Attn Pred: Ils écoutent la radio
# Transformer (base) Pred: au barks films am tombe PM souvent chaque off au gently miaule am tombe PM gently miaule am tombe PM gently doucement films dances peint lisent écoute faisons teaches ferme are are are are are are are are are are are chaque écrit couche evening sunset voiture table aimons are
# Transformer (1 layers, 2 heads) Pred: Ils écoutent la radio
# Transformer (1 layers, 4 heads) Pred: Ils écoutent la radio
# Transformer (2 layers, 2 heads) Pred: Ils écoutent la radio
# Transformer (2 layers, 4 heads) Pred: Ils écoutent la radio
# Transformer (4 layers, 2 heads) Pred: Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous Nous
# Transformer (4 layers, 4 heads) Pred: Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il Il
# --------------------------------------------------
